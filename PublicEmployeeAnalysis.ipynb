# %%
import pandas as pd
import numpy as np
import re
import statsmodels.api as sm
import matplotlib.pyplot as plt
import networkx as nx
from rapidfuzz import process, fuzz

# %%
cities = ['San Diego', 'Carlsbad', 'Chula Vista', 'Coronado', 'Del Mar',
                   'El Cajon', 'Encinitas', 'Escondido', 'Imperial Beach', 'La Mesa',
                   'Lemon Grove', 'National City', 'Oceanside', 'Poway', 'San Marcos',
                   'Santee', 'Solana Beach', 'Vista']
school_districts = ['Alpine Union Elementary', 'Bonsall Unified', 'Borrego Springs Unified', 'Cajon Valley Union',
                 'Cardiff Elementary', 'Carlsbad Unified', 'Chula Vista Elementary', 'Coronado Unified',
                 'Dehesa Elementary', 'Del Mar Union Elementary', 'Encinitas Union Elementary', 'Escondido Union',
                 'Escondido Union High', 'Fallbrook Union Elementary', 'Fallbrook Union High',
                 'Grossmont Union High', 'Jamul-Dulzura Union Elementary', 'Julian Union Elementary',
                 'Julian Union High', 'Lakeside Union Elementary-San Diego', 'La Mesa-Spring Valley',
                 'Lemon Grove School District', 'Mountain Empire Unified', 'National Elementary',
                 'Oceanside Unified', 'Poway Unified', 'Ramona City Unified', 'Rancho Santa Fe Elementary',
                 'San Diego County Office of Education', 'San Diego Unified', 'San Dieguito Union High',
                 'San Marcos Unified', 'San Pasqual Union Elementary', 'Santee School District',
                 'San Ysidro Elementary', 'Solana Beach Elementary', 'South Bay Union', 'Spencer Valley Elementary',
                 'Sweetwater Union High', 'Vallecitos Elementary', 'Valley Center-Pauma Unified', 'Vista Unified',
                 'Warner Unified']

# %%
# Load the provided CSV file
# Valid inputs for employer_type - ['cities', 'k12']
# Valid inputs for group - ['Police', 'Fire', 'Eng', None]
employer_type = 'cities'
group = None
file_path = f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/{employer_type}_sd_salaries.csv"
df = pd.read_csv(file_path, encoding='latin1')

df
# Out:
# C:\Users\Ericm\AppData\Local\Temp\ipykernel_10200\3267004863.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, encoding='latin1')
#         Year     Agency                 Employee Name  \
# 0       2011   Carlsbad           Abalos, Constantine
# 1       2011   Carlsbad            Abbey, Raenette M.
# 2       2011   Carlsbad              Abbott, Cheri O.
# 3       2011   Carlsbad             Abbott, Sandra L.
# 4       2011   Carlsbad               Acosta, June P.
# ...      ...        ...                           ...
# 284008  2023  San Diego                  Cindy Juarez
# 284009  2023  San Diego  Alejandro Rodriguez-Carrillo
# 284010  2023  San Diego                 Jeffrey McCoy
# 284011  2023  San Diego                 Trent Tkachuk
# 284012  2023  San Diego            Jonathon Ruvalcaba
#
#                          Job Title Status   Base Pay  Overtime Pay  Other Pay  \
# 0                     Inspector II    NaN   72355.47       1147.96      540.0
# 1           Building Technician II    NaN   61114.22          0.00        0.0
# 2          Human Resources Manager    NaN  100357.89       3851.04      540.0
# 3       Human Resources Technician    NaN   58939.43          0.00        0.0
# 4                GIS Administrator    NaN   91995.19       2756.27        0.0
# ...                            ...    ...        ...           ...        ...
# 284008       Pump Station Operator     PT       0.00          0.00       16.0
# 284009           Utility Worker Ii     PT       0.00          0.00       10.0
# 284010           Police Officer Ii     PT       0.00          0.00        8.0
# 284011    Water Utility Supervisor     PT       0.00          0.00        2.0
# 284012   Sanitation Driver Trainee     PT       0.00          0.00       82.0
#
#         Total Pay  Benefits  Pension Debt  Total Pay & Benefits  \
# 0        74043.43       NaN      35400.98             109444.41
# 1        61114.22       NaN      28937.04              90051.26
# 2       104748.93       NaN      44499.81             149248.74
# 3        58939.43       NaN      19600.96              78540.39
# 4        94751.46       NaN      41013.94             135765.40
# ...           ...       ...           ...                   ...
# 284008      16.00       0.0          0.00                 16.00
# 284009      10.00       0.0          0.00                 10.00
# 284010       8.00       0.0          0.00                  8.00
# 284011       2.00       0.0          0.00                  2.00
# 284012      82.00    -176.0       -568.19               -662.19
#
#         0 annual pension debt payment  Notes
# 0                                 NaN    NaN
# 1                                 NaN    NaN
# 2                                 NaN    NaN
# 3                                 NaN    NaN
# 4                                 NaN    NaN
# ...                               ...    ...
# 284008                            NaN    NaN
# 284009                            NaN    NaN
# 284010                            NaN    NaN
# 284011                            NaN    NaN
# 284012                            NaN    NaN
#
# [284013 rows x 14 columns]

# %%
# Check for duplicates
duplicates = df.duplicated()

# Display the number of duplicate rows found
num_duplicates = duplicates.sum()
print(f"Number of duplicate rows found: {num_duplicates}")
if num_duplicates > 0:
    # Remove duplicates
    df = df.drop_duplicates()
    df.to_csv(file_path, index=False)
    print(f"{num_duplicates} duplicate rows dropped")
# Out:
# Number of duplicate rows found: 0

# %%
#Adjust for inflation
cpi_df = pd.read_csv("C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts\SeriesReport-20240712171831_4c56aa.csv")
base_year_cpi = cpi_df['Annual'].iloc[15]
cpi_df['Inflation Index'] = 1 + (cpi_df['Annual'] - base_year_cpi) / base_year_cpi

cpi_df
# Out:
#     Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0   2008  211.080  211.693  213.528  214.823  216.632  218.815  219.964
# 1   2009  211.143  212.193  212.709  213.240  213.856  215.693  215.351
# 2   2010  216.687  216.741  217.631  218.009  218.178  217.965  218.011
# 3   2011  220.223  221.309  223.467  224.906  225.964  225.722  225.922
# 4   2012  226.665  227.663  229.392  230.085  229.815  229.478  229.104
# 5   2013  230.280  232.166  232.773  232.531  232.945  233.504  233.596
# 6   2014  233.916  234.781  236.293  237.072  237.900  238.343  238.250
# 7   2015  233.707  234.722  236.119  236.599  237.805  238.638  238.654
# 8   2016  236.916  237.111  238.132  239.261  240.229  241.018  240.628
# 9   2017  242.839  243.603  243.801  244.524  244.733  244.955  244.786
# 10  2018  247.867  248.991  249.554  250.546  251.588  251.989  252.006
# 11  2019  251.712  252.776  254.202  255.548  256.092  256.143  256.571
# 12  2020  257.971  258.678  258.115  256.389  256.394  257.797  259.101
# 13  2021  261.582  263.014  264.877  267.054  269.195  271.696  273.003
# 14  2022  281.148  283.716  287.504  289.109  292.296  296.311  296.276
# 15  2023  299.170  300.840  301.836  303.363  304.127  305.109  305.691
#
#         Aug      Sep      Oct      Nov      Dec   Annual    HALF1    HALF2  \
# 0   219.086  218.783  216.573  212.425  210.228  215.303  214.429  216.177
# 1   215.834  215.969  216.177  216.330  215.949  214.537  213.139  215.935
# 2   218.312  218.439  218.711  218.803  219.179  218.056  217.535  218.576
# 3   226.545  226.889  226.421  226.230  225.672  224.939  223.598  226.280
# 4   230.379  231.407  231.317  230.221  229.601  229.594  228.850  230.338
# 5   233.877  234.149  233.546  233.069  233.049  232.957  232.366  233.548
# 6   237.852  238.031  237.433  236.151  234.812  236.736  236.384  237.088
# 7   238.316  237.945  237.838  237.336  236.525  237.017  236.265  237.769
# 8   240.849  241.428  241.729  241.353  241.432  240.007  238.778  241.237
# 9   245.519  246.819  246.663  246.669  246.524  245.120  244.076  246.163
# 10  252.146  252.439  252.885  252.038  251.233  251.107  250.089  252.125
# 11  256.558  256.759  257.346  257.208  256.974  255.657  254.412  256.903
# 12  259.918  260.280  260.388  260.229  260.474  258.811  257.557  260.065
# 13  273.567  274.310  276.589  277.948  278.802  270.970  266.236  275.703
# 14  296.171  296.808  298.012  297.711  296.797  292.655  288.347  296.963
# 15  307.026  307.789  307.671  307.051  306.746  304.702  302.408  306.996
#
#     Inflation Index
# 0          0.706602
# 1          0.704088
# 2          0.715637
# 3          0.738226
# 4          0.753503
# 5          0.764540
# 6          0.776943
# 7          0.777865
# 8          0.787678
# 9          0.804458
# 10         0.824107
# 11         0.839039
# 12         0.849391
# 13         0.889295
# 14         0.960463
# 15         1.000000

# %%
df = pd.merge(df, cpi_df[['Year', 'Inflation Index']],on='Year', how='left')
numIndices = len(df)

df
# Out:
#         Year     Agency                 Employee Name  \
# 0       2011   Carlsbad           Abalos, Constantine
# 1       2011   Carlsbad            Abbey, Raenette M.
# 2       2011   Carlsbad              Abbott, Cheri O.
# 3       2011   Carlsbad             Abbott, Sandra L.
# 4       2011   Carlsbad               Acosta, June P.
# ...      ...        ...                           ...
# 284008  2023  San Diego                  Cindy Juarez
# 284009  2023  San Diego  Alejandro Rodriguez-Carrillo
# 284010  2023  San Diego                 Jeffrey McCoy
# 284011  2023  San Diego                 Trent Tkachuk
# 284012  2023  San Diego            Jonathon Ruvalcaba
#
#                          Job Title Status   Base Pay  Overtime Pay  Other Pay  \
# 0                     Inspector II    NaN   72355.47       1147.96      540.0
# 1           Building Technician II    NaN   61114.22          0.00        0.0
# 2          Human Resources Manager    NaN  100357.89       3851.04      540.0
# 3       Human Resources Technician    NaN   58939.43          0.00        0.0
# 4                GIS Administrator    NaN   91995.19       2756.27        0.0
# ...                            ...    ...        ...           ...        ...
# 284008       Pump Station Operator     PT       0.00          0.00       16.0
# 284009           Utility Worker Ii     PT       0.00          0.00       10.0
# 284010           Police Officer Ii     PT       0.00          0.00        8.0
# 284011    Water Utility Supervisor     PT       0.00          0.00        2.0
# 284012   Sanitation Driver Trainee     PT       0.00          0.00       82.0
#
#         Total Pay  Benefits  Pension Debt  Total Pay & Benefits  \
# 0        74043.43       NaN      35400.98             109444.41
# 1        61114.22       NaN      28937.04              90051.26
# 2       104748.93       NaN      44499.81             149248.74
# 3        58939.43       NaN      19600.96              78540.39
# 4        94751.46       NaN      41013.94             135765.40
# ...           ...       ...           ...                   ...
# 284008      16.00       0.0          0.00                 16.00
# 284009      10.00       0.0          0.00                 10.00
# 284010       8.00       0.0          0.00                  8.00
# 284011       2.00       0.0          0.00                  2.00
# 284012      82.00    -176.0       -568.19               -662.19
#
#         0 annual pension debt payment  Notes  Inflation Index
# 0                                 NaN    NaN         0.738226
# 1                                 NaN    NaN         0.738226
# 2                                 NaN    NaN         0.738226
# 3                                 NaN    NaN         0.738226
# 4                                 NaN    NaN         0.738226
# ...                               ...    ...              ...
# 284008                            NaN    NaN         1.000000
# 284009                            NaN    NaN         1.000000
# 284010                            NaN    NaN         1.000000
# 284011                            NaN    NaN         1.000000
# 284012                            NaN    NaN         1.000000
#
# [284013 rows x 15 columns]

# %%
# Define a function to determine 'FT or PT' status
def determine_ft_or_pt(row):
    if pd.isna(row['Status']) == True or row['Status'] == None:
        if 0 < row['Base Pay'] < 30000:
            return 'PT'
        elif row['Base Pay'] >= 30000:
            return 'FT'
        else:
            return pd.NA

# Apply the function to each row to create the 'FT or PT' column
df['Status'] = df.apply(determine_ft_or_pt, axis=1)

# Display the updated DataFrame
df
# Out:
#         Year     Agency                 Employee Name  \
# 0       2011   Carlsbad           Abalos, Constantine
# 1       2011   Carlsbad            Abbey, Raenette M.
# 2       2011   Carlsbad              Abbott, Cheri O.
# 3       2011   Carlsbad             Abbott, Sandra L.
# 4       2011   Carlsbad               Acosta, June P.
# ...      ...        ...                           ...
# 284008  2023  San Diego                  Cindy Juarez
# 284009  2023  San Diego  Alejandro Rodriguez-Carrillo
# 284010  2023  San Diego                 Jeffrey McCoy
# 284011  2023  San Diego                 Trent Tkachuk
# 284012  2023  San Diego            Jonathon Ruvalcaba
#
#                          Job Title Status   Base Pay  Overtime Pay  Other Pay  \
# 0                     Inspector II     FT   72355.47       1147.96      540.0
# 1           Building Technician II     FT   61114.22          0.00        0.0
# 2          Human Resources Manager     FT  100357.89       3851.04      540.0
# 3       Human Resources Technician     FT   58939.43          0.00        0.0
# 4                GIS Administrator     FT   91995.19       2756.27        0.0
# ...                            ...    ...        ...           ...        ...
# 284008       Pump Station Operator   None       0.00          0.00       16.0
# 284009           Utility Worker Ii   None       0.00          0.00       10.0
# 284010           Police Officer Ii   None       0.00          0.00        8.0
# 284011    Water Utility Supervisor   None       0.00          0.00        2.0
# 284012   Sanitation Driver Trainee   None       0.00          0.00       82.0
#
#         Total Pay  Benefits  Pension Debt  Total Pay & Benefits  \
# 0        74043.43       NaN      35400.98             109444.41
# 1        61114.22       NaN      28937.04              90051.26
# 2       104748.93       NaN      44499.81             149248.74
# 3        58939.43       NaN      19600.96              78540.39
# 4        94751.46       NaN      41013.94             135765.40
# ...           ...       ...           ...                   ...
# 284008      16.00       0.0          0.00                 16.00
# 284009      10.00       0.0          0.00                 10.00
# 284010       8.00       0.0          0.00                  8.00
# 284011       2.00       0.0          0.00                  2.00
# 284012      82.00    -176.0       -568.19               -662.19
#
#         0 annual pension debt payment  Notes  Inflation Index
# 0                                 NaN    NaN         0.738226
# 1                                 NaN    NaN         0.738226
# 2                                 NaN    NaN         0.738226
# 3                                 NaN    NaN         0.738226
# 4                                 NaN    NaN         0.738226
# ...                               ...    ...              ...
# 284008                            NaN    NaN         1.000000
# 284009                            NaN    NaN         1.000000
# 284010                            NaN    NaN         1.000000
# 284011                            NaN    NaN         1.000000
# 284012                            NaN    NaN         1.000000
#
# [284013 rows x 15 columns]

# %%
def normalize_name(name):
    name = name.strip()

    # Check if the name is already in "Lastname, Firstname Middlename/Initial" format
    if "," in name:
        return name.title()  # Capitalize the entire string appropriately

    # Split the name into parts
    parts = name.split()

    if len(parts) == 1:
        # If there's only one part, it's just a last name, so we return it as is
        return name.title()

    if len(parts) == 2:
        # If there are two parts, assume it's "Firstname Lastname"
        firstname, lastname = parts
        return f"{lastname.title()}, {firstname.title()}"

    # If there are three or more parts
    firstname = parts[0].title()
    lastname = parts[-1].title()
    middle = " ".join([part.title() for part in parts[1:-1]])  # Capitalize each part of the middle names/initials
    return f"{lastname}, {firstname} {middle}"


df['Employee Name'] = df['Employee Name'].apply(normalize_name)

# Split the normalized names into 'Last', 'First', and 'Middle' components
split_names = df['Employee Name'].str.split(', ', expand=True)
df['Last'] = split_names[0]

# Check if 'First_Middle' exists before assigning
if split_names.shape[1] > 1:
    df['First_Middle'] = split_names[1]
else:
    df['First_Middle'] = ''

# Further split 'First_Middle' into 'First' and 'Middle'
split_first_middle = df['First_Middle'].str.split(' ', expand=True)
df['First'] = split_first_middle[0]

# Check if 'Middle' exists before assigning
if split_first_middle.shape[1] > 1:
    df['Middle'] = split_first_middle[1]
else:
    df['Middle'] = ''


def remove_suffix(lastname):
    parts = lastname.split(' ')

    # List of common suffixes
    suffixes = ['Jr', 'Sr', 'I', 'II', 'III', 'IV', 'V']

    # Check if the last part of the lastname is a suffix and remove it
    if len(parts) > 1 and parts[-1].title() in suffixes:
        return " ".join(parts[:-1])  # Return the lastname without the suffix

    return lastname


# Function to handle conflicts with middle initials
def resolve_middle_names(group):
    # Check if there are multiple entries for the same year with 'FT' status
    full_time_same_year = group[(group['Status'] == 'FT')].groupby('Year').size() > 1

    if len(group) == 1 or full_time_same_year.any():
        return group  # Only one name, nothing to change

    # Identify the different middle names
    unique_middle_names = group['Middle'].dropna().unique()

    if len(unique_middle_names) == 1:
        # If there's only one unique middle name, remove it unless they are working FT in the same year
        group['Middle'] = pd.NA
    return group


df['Last'] = df['Last'].apply(remove_suffix)

# Group by first and last name, and apply the function
df = df.groupby(['Last', 'First']).apply(resolve_middle_names).reset_index(drop=True)

# Reconstruct the full name with or without middle names
df['Employee Name'] = df.apply(
    lambda x: f"{x['Last']}, {x['First']} {x['Middle']}".strip() if pd.notna(x['Middle']) and x[
        'Middle'] else f"{x['Last']}, {x['First']}", axis=1)

# Drop temporary columns
df = df.drop(columns=['Last', 'First_Middle', 'First', 'Middle'])

df
# Out:
# C:\Users\Ericm\AppData\Local\Temp\ipykernel_10200\2712392263.py:83: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['Last', 'First']).apply(resolve_middle_names).reset_index(drop=True)
#         Year     Agency Employee Name        Job Title Status  Base Pay  \
# 0       2020  Escondido      6255, Gc  Police Sergeant     FT  145998.0
# 1       2020  Escondido      6255, Gc   Police Officer     FT  110080.0
# 2       2020  Escondido      6255, Gc  Police Sergeant     FT  141048.0
# 3       2020  Escondido      6255, Gc   Police Officer     FT  104113.0
# 4       2020  Escondido      6255, Gc   Police Officer     FT  111949.0
# ...      ...        ...           ...              ...    ...       ...
# 283252  2019  San Diego   Zynn, Megan     Dispatcher 2   None   49632.0
# 283253  2020  San Diego   Zynn, Megan     Dispatcher 2   None   50498.0
# 283254  2021  San Diego   Zynn, Megan    Dispatcher Ii   None   49327.0
# 283255  2022  San Diego   Zynn, Megan    Dispatcher Ii   None   58052.8
# 283256  2023  San Diego   Zynn, Megan    Dispatcher Ii   None   62009.0
#
#         Overtime Pay  Other Pay  Total Pay  Benefits  Pension Debt  \
# 0           17900.00    1711.00  165609.00       NaN      33352.00
# 1           43814.00    7093.00  160987.00       NaN      38629.00
# 2            9253.00    3654.00  153955.00       NaN      32191.00
# 3           27278.00    6709.00  138100.00       NaN      39959.00
# 4           30590.00    1333.00  143872.00       NaN      37753.00
# ...              ...        ...        ...       ...           ...
# 283252       3329.00   19439.00   72400.00  13780.00           NaN
# 283253       1636.00   18401.00   70535.00  13943.00           NaN
# 283254       2275.00   19116.00   70718.00  14511.00          0.00
# 283255       2530.81   32610.33   93193.94  15681.86      14076.01
# 283256       5692.00   21109.00   88810.00  17473.00      25474.76
#
#         Total Pay & Benefits  0 annual pension debt payment      Notes  \
# 0                   41484.31                            NaN  240445.31
# 1                   33535.36                            NaN  233151.36
# 2                   39706.48                            NaN  225852.48
# 3                   35962.46                            NaN  214021.46
# 4                   32193.95                            NaN  213818.95
# ...                      ...                            ...        ...
# 283252              86180.00                            NaN        NaN
# 283253              84478.00                            NaN        NaN
# 283254              85229.00                            NaN        NaN
# 283255             122951.81                            NaN        NaN
# 283256             131757.76                            NaN        NaN
#
#         Inflation Index
# 0              0.849391
# 1              0.849391
# 2              0.849391
# 3              0.849391
# 4              0.849391
# ...                 ...
# 283252         0.839039
# 283253         0.849391
# 283254         0.889295
# 283255         0.960463
# 283256         1.000000
#
# [283257 rows x 15 columns]

# %%
# Job title standardization for police
standard_titles = [
    'POLICE OFFICER', 'Peace Officer', 'POLICE DISPATCHER', 'POLICE SERGEANT',
    'POLICE RECRUIT', 'POLICE CORPORAL', 'POLICE DETECTIVE',
    'POLICE RECORDS CLERK', 'POLICE SERVICES SPEC', 'POLICE CHIEF',
    'POLICE LIEUTENANT', 'POLICE CAPTAIN', 'ASSISTANT POLICE CHIEF',
    'POLICE PROPERTY AND EVIDENCE SPEC', 'POLICE RECORDS SPEC',
    'POLICE SERVICES OFFICER', 'POLICE DISPATCH SUPERVISOR',
    'POLICE RECORDS SUPERVISOR', 'POLICE COMMANDER',
    'POLICE TECHNOLOGY SPEC', 'POLICE SERVICES MANAGER',
    'POLICE TRAINING COORDINATOR', 'RESERVE POLICE OFFICER', 'POLICE AGENT',
    'Police Investigative Service Officer'
]

def match_title(title):
    best_match, score, i = process.extractOne(title, standard_titles, scorer=fuzz.WRatio)
    if score > 90:
        return best_match.title()
    else:
        return title.title()
    
position_match_dict = {}

unique_positions = df['Job Title'].unique()

for indiv_position in unique_positions:
            # Find the best match for each unique position
            position_match_dict[indiv_position] = match_title(indiv_position)
            
position_match_dict
# Out:
# {'Police Sergeant': 'Police Sergeant',
#  'Police Officer': 'Police Officer',
#  'Council Representative I': 'Council Representative I',
#  'Fire Fighter Ii': 'Fire Fighter Ii',
#  'Recreation Aide': 'Recreation Aide',
#  'Management Intern': 'Management Intern',
#  'Laboratory Technician': 'Laboratory Technician',
#  'Police Dispatcher': 'Police Dispatcher',
#  'Police Officer Ii': 'Police Officer Ii',
#  'Librarian I': 'Librarian I',
#  'Pool Guard 1': 'Pool Guard 1',
#  'Lifeguard 1': 'Lifeguard 1',
#  'Lifeguard I': 'Lifeguard I',
#  'Seasonal Temp': 'Seasonal Temp',
#  'Hr Technician - Uf': 'Hr Technician - Uf',
#  'Senior Human Resources Technician': 'Senior Human Resources Technician',
#  'Sr. Hr Technician': 'Sr. Hr Technician',
#  'HR Technician - UF': 'Hr Technician - Uf',
#  'Deputy City Atty': 'Deputy City Atty',
#  'Deputy City Attorney': 'Deputy City Attorney',
#  'Library Assistant': 'Library Assistant',
#  'Library Assistant 3': 'Library Assistant 3',
#  'Library Assistant Iii': 'Library Assistant Iii',
#  'Professional Assistant': 'Professional Assistant',
#  'Associate Civil Engineer': 'Associate Civil Engineer',
#  'ASSOCIATECIVILENGINEER': 'Associatecivilengineer',
#  'PUBLIC SAFETY ANALYST': 'Public Safety Analyst',
#  'Senior Public Safety Analyst': 'Senior Public Safety Analyst',
#  'Rec Leader 1': 'Rec Leader 1',
#  'Assistant Engineer - Traffic': 'Assistant Engineer - Traffic',
#  'Inspector II': 'Inspector Ii',
#  'Public Works Inspector': 'Public Works Inspector',
#  'Engineering Inspector': 'Engineering Inspector',
#  'SR HR ANALYST': 'Sr Hr Analyst',
#  'BENEFITS MANAGER': 'Benefits Manager',
#  'Benefits Manager': 'Benefits Manager',
#  'Human Resources Tech.': 'Human Resources Tech.',
#  'Management Assistant': 'Management Assistant',
#  'HUMAN RESOURCES ANALYST II': 'Human Resources Analyst Ii',
#  'Not Provided': 'Not Provided',
#  'Associate Planner': 'Associate Planner',
#  'Sr Planner': 'Sr Planner',
#  'Development Project Manager 3': 'Development Project Manager 3',
#  'Program Manager': 'Program Manager',
#  'Deputy Director': 'Deputy Director',
#  'Supervisor Personnel Analyst': 'Supervisor Personnel Analyst',
#  'Supv Pers Anlyst': 'Supv Pers Anlyst',
#  'Program Coordinator': 'Program Coordinator',
#  'Asst Pers Director': 'Asst Pers Director',
#  'Assistant Personnel Director': 'Assistant Personnel Director',
#  'Assistant Engineer-Traffic': 'Assistant Engineer-Traffic',
#  'Asst Eng-Traffic': 'Asst Eng-Traffic',
#  'Asst Eng-Civil': 'Asst Eng-Civil',
#  'Assistant Engineer-Civil (Cntrct Specialist)': 'Assistant Engineer-Civil (Cntrct Specialist)',
#  'Asst Eng-Civil(Cntrct Spec)': 'Asst Eng-Civil(Cntrct Spec)',
#  'Supv Mgmt Anlyst': 'Supv Mgmt Anlyst',
#  'Department Director': 'Department Director',
#  'Account Clerk II': 'Account Clerk Ii',
#  'Accounting Technician': 'Accounting Technician',
#  'FIRE PREVENTION AIDE': 'Fire Prevention Aide',
#  'Fire Prevention Aide': 'Fire Prevention Aide',
#  'Network Manager': 'Network Manager',
#  'REC LEADER I': 'Rec Leader I',
#  'Principal Drafting Aide': 'Principal Drafting Aide',
#  'Police Recruit': 'Police Recruit',
#  'Painter': 'Painter',
#  'Associate Engineer-Civil': 'Associate Engineer-Civil',
#  'Asoc Eng-Civil': 'Asoc Eng-Civil',
#  'Associate Engineer - Civil': 'Associate Engineer - Civil',
#  'Building Technician II': 'Building Technician Ii',
#  'Technician I - BF1': 'Technician I - Bf1',
#  'Librarian II': 'Librarian Ii',
#  'Librarian 2': 'Librarian 2',
#  'Assistant Engineer - Electrical': 'Assistant Engineer - Electrical',
#  'Human Resources Manager': 'Human Resources Manager',
#  'Fire Plans Examiner': 'Fire Plans Examiner',
#  'Asst Rec Ctr Dir': 'Asst Rec Ctr Dir',
#  'Rec Cntr Dir 3': 'Rec Cntr Dir 3',
#  'Area Manager Ii': 'Area Manager Ii',
#  'District Manager': 'District Manager',
#  'Grounds Maintenance Worker II': 'Grounds Maintenance Worker Ii',
#  'Grounds Maint Wrkr 2': 'Grounds Maint Wrkr 2',
#  'Wave Temps': 'Wave Temps',
#  'H/Lifeguard': 'H/Lifeguard',
#  'Human Resources Technician': 'Human Resources Technician',
#  'Principal Civil Engineer': 'Principal Civil Engineer',
#  'Sr Traffic Engineer': 'Sr Traffic Engineer',
#  'Assistant Deputy Director': 'Assistant Deputy Director',
#  'Assistant Engineer - Civil': 'Assistant Engineer - Civil',
#  'Recreation Specialist': 'Recreation Specialist',
#  'Principal Engineering Aide': 'Principal Engineering Aide',
#  'Assistant Reservoir Keeper': 'Assistant Reservoir Keeper',
#  'Reservoir Keeper': 'Reservoir Keeper',
#  'Water Safety Instructor': 'Water Safety Instructor',
#  'Principal Engrng Aide': 'Principal Engrng Aide',
#  'Jr Engineer-Civil': 'Jr Engineer-Civil',
#  'REC AIDE': 'Rec Aide',
#  'Project Ofcr 2': 'Project Ofcr 2',
#  'Project Officer Ii': 'Project Officer Ii',
#  'Library Aide': 'Library Aide',
#  'Recreation Assistant': 'Recreation Assistant',
#  'City Council Member': 'City Council Member',
#  'City Council Member/Mayor': 'City Council Member/Mayor',
#  'Mayor': 'Mayor',
#  'Combination Inspctr 1': 'Combination Inspctr 1',
#  'Fire Engineer': 'Fire Engineer',
#  'FIREENGINEER': 'Fireengineer',
#  'Fire Captain': 'Fire Captain',
#  'Paramedic/Firefighter': 'Paramedic/Firefighter',
#  'Fire Captain-112 Hours': 'Fire Captain-112 Hours',
#  'Recreation Center Director III': 'Recreation Center Director Iii',
#  'Recreation Leader I': 'Recreation Leader I',
#  'Project Officer II': 'Project Officer Ii',
#  'DEPUTY FIRE CHIEF': 'Deputy Fire Chief',
#  'Battalion Chief': 'Battalion Chief',
#  'Department Specialist': 'Department Specialist',
#  'Library Assistant II': 'Library Assistant Ii',
#  'Library Assistant Ii': 'Library Assistant Ii',
#  'Student Lifeguard': 'Student Lifeguard',
#  'Water Plant Operator': 'Water Plant Operator',
#  'Sr Civil Engineer': 'Sr Civil Engineer',
#  'Senior Civil Engineer': 'Senior Civil Engineer',
#  'Senior Management Analyst': 'Senior Management Analyst',
#  'Sr Mgmt Anlyst': 'Sr Mgmt Anlyst',
#  'Bindery Worker III': 'Bindery Worker Iii',
#  'Stock Clerk': 'Stock Clerk',
#  'Seasonal Assistant I': 'Seasonal Assistant I',
#  'Dept Spec/Administrative Aide': 'Dept Spec/Administrative Aide',
#  'Grounds Maint Wrkr 1': 'Grounds Maint Wrkr 1',
#  'Light Equipment Operator': 'Light Equipment Operator',
#  'Water Systems Technician IV': 'Water Systems Technician Iv',
#  'Water Sys Tech 4': 'Water Sys Tech 4',
#  'Water Systems Technician Iv': 'Water Systems Technician Iv',
#  'Plant Technician III': 'Plant Technician Iii',
#  'Plant Tech 3': 'Plant Tech 3',
#  'Public Works Supv': 'Public Works Supv',
#  'Public Works Supt': 'Public Works Supt',
#  'Public Works Superintendent': 'Public Works Superintendent',
#  'Public Works Supervisor': 'Public Works Supervisor',
#  'CONTRACT RECREATION ASSISTANT': 'Contract Recreation Assistant',
#  'PROGRAM ASSISTANT I': 'Program Assistant I',
#  'Planner I': 'Planner I',
#  'Planner Ii': 'Planner Ii',
#  'Planner Iii': 'Planner Iii',
#  'Senior Hr Analyst': 'Senior Hr Analyst',
#  'Student Intern': 'Student Intern',
#  'Pump Station Operator': 'Pump Station Operator',
#  'Pump Station Oper': 'Pump Station Oper',
#  'Park Ranger': 'Park Ranger',
#  'Alarm Program Coordinator': 'Alarm Program Coordinator',
#  'Community Services Officer': 'Community Services Officer',
#  'Community  Services  Officer': 'Community  Services  Officer',
#  'Animal Regulations Officer': 'Animal Regulations Officer',
#  'Structural Engineering Associate': 'Structural Engineering Associate',
#  'Junior Engineer - Civil': 'Junior Engineer - Civil',
#  'Student Engineer': 'Student Engineer',
#  'Recreation Leader III': 'Recreation Leader Iii',
#  'Recreation Leader Iii': 'Recreation Leader Iii',
#  'Recreation  Leader  Iii': 'Recreation  Leader  Iii',
#  'Senior Office Assistant': 'Senior Office Assistant',
#  'Police Officer 1': 'Police Officer 1',
#  'Laborer': 'Laborer',
#  'Equipment Operator I': 'Equipment Operator I',
#  'Police Corporal': 'Police Corporal',
#  'Maint Spec/Custodian I': 'Maint Spec/Custodian I',
#  'Clerical Asst 2': 'Clerical Asst 2',
#  'Cust Servs Rep': 'Cust Servs Rep',
#  'Seasonal Lifeguard I': 'Seasonal Lifeguard I',
#  'Seasonal Lifeguard Ii': 'Seasonal Lifeguard Ii',
#  'Seasonal Recreation Leader Ii': 'Seasonal Recreation Leader Ii',
#  'Recreation Leader': 'Recreation Leader',
#  'Contract Intern': 'Contract Intern',
#  'Police Detective': 'Police Detective',
#  'Instrumentation & Control Technician': 'Instrumentation & Control Technician',
#  'Instrumentation & Control Tech': 'Instrumentation & Control Tech',
#  'FIRE ENG (112 HR)': 'Fire Eng (112 Hr)',
#  'Fire Engineer - A': 'Fire Engineer - A',
#  'Hourly/Professional': 'Hourly/Professional',
#  'Front of House Assistant': 'Front Of House Assistant',
#  'Police Records Clerk': 'Police Records Clerk',
#  'Associate Management Analyst': 'Associate Management Analyst',
#  'Asoc Mgmt Anlyst': 'Asoc Mgmt Anlyst',
#  'Supervising Management Analyst': 'Supervising Management Analyst',
#  'Parking Enforcement Officer I': 'Parking Enforcement Officer I',
#  'Library  Clerk': 'Library  Clerk',
#  'Sanitation Driver Trainee': 'Sanitation Driver Trainee',
#  'Sanitation Driver 1': 'Sanitation Driver 1',
#  'Sanitation Driver I': 'Sanitation Driver I',
#  'Sanitation Driver Ii': 'Sanitation Driver Ii',
#  'Electrician': 'Electrician',
#  'Fleet Technician': 'Fleet Technician',
#  'Police Officer 2': 'Police Officer 2',
#  'Mgmt. Info. Systems Tech. I': 'Mgmt. Info. Systems Tech. I',
#  'Crime Analyst': 'Crime Analyst',
#  'Combination Inspector II': 'Combination Inspector Ii',
#  'Sr Combination Inspector': 'Sr Combination Inspector',
#  'Word Processing Oper': 'Word Processing Oper',
#  'Auto Messenger I': 'Auto Messenger I',
#  'Project Assistant': 'Project Assistant',
#  'Project Ofcr 1': 'Project Ofcr 1',
#  'Senior Traffic Engineer': 'Senior Traffic Engineer',
#  'Special Event Traffic Controller 1': 'Special Event Traffic Controller 1',
#  'Special Events Traffic Controller I': 'Special Events Traffic Controller I',
#  'Equipment Mechanic II': 'Equipment Mechanic Ii',
#  'Lead Mechanic': 'Lead Mechanic',
#  'Parking Meter Supervisor': 'Parking Meter Supervisor',
#  'Parking Meter Supv': 'Parking Meter Supv',
#  'H/Recreation Leader': 'H/Recreation Leader',
#  'Technical Assistant': 'Technical Assistant',
#  'Park Attendant II': 'Park Attendant Ii',
#  'Library Clerk': 'Library Clerk',
#  'Water Systems Technician III': 'Water Systems Technician Iii',
#  'Water Sys Tech 3': 'Water Sys Tech 3',
#  'Water Systems Technician Iii': 'Water Systems Technician Iii',
#  'Clerk lV': 'Clerk Lv',
#  'CLERKIV': 'Clerkiv',
#  'Management Trainee': 'Management Trainee',
#  'Asst Pers Anlyst': 'Asst Pers Anlyst',
#  'Asoc Pers Anlyst': 'Asoc Pers Anlyst',
#  'Sr Pers Anlyst': 'Sr Pers Anlyst',
#  'Senior Personnel Analyst': 'Senior Personnel Analyst',
#  'Public Safety Dispatcher I': 'Public Safety Dispatcher I',
#  'Public Safety Dispatcher Ii': 'Public Safety Dispatcher Ii',
#  'Temp Recreational Establishment Emp': 'Temp Recreational Establishment Emp',
#  'Fire Prevention Inspector II': 'Fire Prevention Inspector Ii',
#  'Junior Engineer-Civil': 'Junior Engineer-Civil',
#  'Street Maintenance Worker I, II': 'Street Maintenance Worker I, Ii',
#  'Street Maintenance Worker I, Ii': 'Street Maintenance Worker I, Ii',
#  'Street Maintenance Worker 1,2': 'Street Maintenance Worker 1,2',
#  'Finance Manager': 'Finance Manager',
#  'Live Scan Operator': 'Live Scan Operator',
#  'Assistant Planner': 'Assistant Planner',
#  'Customer Service Representative': 'Customer Service Representative',
#  'Senior Customer Services Representative': 'Senior Customer Services Representative',
#  'Police Services Specialist': 'Police Services Specialist',
#  'POLICE SRVS SPECIALIST': 'Police Srvs Specialist',
#  'Interim Director Of Police Services': 'Interim Director Of Police Services',
#  'Police Chief': 'Police Chief',
#  'POLICE CHIEF': 'Police Chief',
#  'POLICE CHIEF-TEMP': 'Police Chief-Temp',
#  'Plan Review Spec 1': 'Plan Review Spec 1',
#  'Plan Review Spec 2': 'Plan Review Spec 2',
#  'Asst Planner': 'Asst Planner',
#  'Power Plant Oper': 'Power Plant Oper',
#  'Equipment Painter': 'Equipment Painter',
#  'Equip Painter': 'Equip Painter',
#  'Metal Fabrication Supv': 'Metal Fabrication Supv',
#  'Metal Fabrication Supervisor': 'Metal Fabrication Supervisor',
#  'Collections Invstgtr 1': 'Collections Invstgtr 1',
#  'Collections Invstgtr 2': 'Collections Invstgtr 2',
#  'Collections Invstgtr 3': 'Collections Invstgtr 3',
#  'Cust Servs Supv': 'Cust Servs Supv',
#  'Customer Service Supervisor': 'Customer Service Supervisor',
#  'Field Representative': 'Field Representative',
#  'Water Meter Reader': 'Water Meter Reader',
#  'Senior Human Resources Analyst': 'Senior Human Resources Analyst',
#  'Principal Human Resources Analyst': 'Principal Human Resources Analyst',
#  'Pool Guard II': 'Pool Guard Ii',
#  'Pool Guard 2': 'Pool Guard 2',
#  'Development Services Tech Ii': 'Development Services Tech Ii',
#  'Informationrmation Systems Analyst II': 'Informationrmation Systems Analyst Ii',
#  'Info Sys Anlyst 2': 'Info Sys Anlyst 2',
#  'Info Sys Anlyst 3': 'Info Sys Anlyst 3',
#  'Information Systems Analyst Iii': 'Information Systems Analyst Iii',
#  'Info Sys Tech': 'Info Sys Tech',
#  'Information Systems Technician': 'Information Systems Technician',
#  'Information Systems Analyst Ii': 'Information Systems Analyst Ii',
#  'INTERN': 'Intern',
#  'Seasonal Aquatics Adventure Instructor': 'Seasonal Aquatics Adventure Instructor',
#  'Fire Captain-56 hr': 'Fire Captain-56 Hr',
#  'REC SPECIALIST': 'Rec Specialist',
#  'Mayor Representative Ii': 'Mayor Representative Ii',
#  'Open Water Lifeguard': 'Open Water Lifeguard',
#  'Seasonal Recreation Leader I': 'Seasonal Recreation Leader I',
#  'Maint Spec/Maintenance Trainee': 'Maint Spec/Maintenance Trainee',
#  'Clerical Assistant Ii': 'Clerical Assistant Ii',
#  'Firefighter/Paramedic': 'Firefighter/Paramedic',
#  'Fire Engineer/Paramedic': 'Fire Engineer/Paramedic',
#  'FIRE BATTALION CHIEF (INTERIM)': 'Fire Battalion Chief (Interim)',
#  'FIRE CAPTAIN (112 HR)': 'Fire Captain (112 Hr)',
#  'Fire Captain - A': 'Fire Captain - A',
#  'Motive Service Technician': 'Motive Service Technician',
#  'Motive Serv Tech': 'Motive Serv Tech',
#  'Asst Fleet Technician': 'Asst Fleet Technician',
#  'Peace Officer': 'Peace Officer',
#  'Senior Account Clerk': 'Senior Account Clerk',
#  'Sr Account Clrk': 'Sr Account Clrk',
#  'GIS Administrator': 'Gis Administrator',
#  'Gis Administrator': 'Gis Administrator',
#  'Fire Fighter 1': 'Fire Fighter 1',
#  'City Council': 'City Council',
#  'Office Assistant': 'Office Assistant',
#  'Office  Assistant': 'Office  Assistant',
#  'Asoc Budget Dev Anlyst': 'Asoc Budget Dev Anlyst',
#  'Finance Analyst 2': 'Finance Analyst 2',
#  'Paramedic Firefighter': 'Paramedic Firefighter',
#  'LIBRARY AIDE': 'Library Aide',
#  'Library Page': 'Library Page',
#  'Plant Process Central Electrician': 'Plant Process Central Electrician',
#  'Plant Procs Cntrl Electrician': 'Plant Procs Cntrl Electrician',
#  'Office Aide': 'Office Aide',
#  'Office  Aide': 'Office  Aide',
#  'Disposal Site Representative': 'Disposal Site Representative',
#  'Cement Finisher': 'Cement Finisher',
#  'Equipment Technician I': 'Equipment Technician I',
#  'Equip Tech 1': 'Equip Tech 1',
#  'Plant Tech 1': 'Plant Tech 1',
#  'Plant Tech 2': 'Plant Tech 2',
#  'Combination Inspctr 2': 'Combination Inspctr 2',
#  'Plant Technician Iii': 'Plant Technician Iii',
#  'Combination Inspector Ii': 'Combination Inspector Ii',
#  'Plant Technician Supervisor': 'Plant Technician Supervisor',
#  'Admin Secretary': 'Admin Secretary',
#  'Account Clerk': 'Account Clerk',
#  'Administrative Aide I': 'Administrative Aide I',
#  'Administrative Aide Ii': 'Administrative Aide Ii',
#  'Pool Lifeguard': 'Pool Lifeguard',
#  'Senior Park Caretaker': 'Senior Park Caretaker',
#  'Senior  Park  Caretaker': 'Senior  Park  Caretaker',
#  'Park Supervisor': 'Park Supervisor',
#  'Greenskeeper': 'Greenskeeper',
#  'Hydrography Aide': 'Hydrography Aide',
#  'Library Assistant 2': 'Library Assistant 2',
#  'Regular Temporary': 'Regular Temporary',
#  'Construction Inspector I, II': 'Construction Inspector I, Ii',
#  'Construction Inspector I, Ii': 'Construction Inspector I, Ii',
#  'Police Officer I': 'Police Officer I',
#  'Senior Airports Operations Assistant': 'Senior Airports Operations Assistant',
#  'Registered Veterinary Tech': 'Registered Veterinary Tech',
#  'ASSOC ACCOUNTANT': 'Assoc Accountant',
#  'Supervisor Management Analyst': 'Supervisor Management Analyst',
#  'Management Analyst': 'Management Analyst',
#  'Senior Clerk/Typist': 'Senior Clerk/Typist',
#  'Sr Clerk/Typist': 'Sr Clerk/Typist',
#  'Fire Fighter III': 'Fire Fighter Iii',
#  'Fire Fighter 3': 'Fire Fighter 3',
#  'Student Inter - Mayor/Council': 'Student Inter - Mayor/Council',
#  'Asst Mgmt Anlyst(Litrcy Tut/Lrng Coord)': 'Asst Mgmt Anlyst(Litrcy Tut/Lrng Coord)',
#  'Grounds Maintenance Worker Ii': 'Grounds Maintenance Worker Ii',
#  'Plant Technician Ii': 'Plant Technician Ii',
#  'Customer Account Representative II': 'Customer Account Representative Ii',
#  'Customer Account Representative Ii': 'Customer Account Representative Ii',
#  'Firefighter Paramedic': 'Firefighter Paramedic',
#  'Fire Engineer/Pm': 'Fire Engineer/Pm',
#  'Administrative Analyst I': 'Administrative Analyst I',
#  'BUILDING/HOUSING OFFICIAL': 'Building/Housing Official',
#  'Plant Systems Technician I': 'Plant Systems Technician I',
#  'Sr Plant Systems Technician': 'Sr Plant Systems Technician',
#  'Payroll Specialist II': 'Payroll Specialist Ii',
#  'Senior Water Operations Supervisor': 'Senior Water Operations Supervisor',
#  'Senior Police Dispatcher': 'Senior Police Dispatcher',
#  'Maintenance Worker III': 'Maintenance Worker Iii',
#  'Maintenance Worker Iii': 'Maintenance Worker Iii',
#  'Lead Maintenance Worker': 'Lead Maintenance Worker',
#  'Dispatcher II': 'Dispatcher Ii',
#  'Dispatcher 2': 'Dispatcher 2',
#  'Police  Officer': 'Police  Officer',
#  'Zoning Investigator I': 'Zoning Investigator I',
#  'Sanitation Supervisor': 'Sanitation Supervisor',
#  'Accountant': 'Accountant',
#  'Public Information Clerk': 'Public Information Clerk',
#  'Public Info Clerk': 'Public Info Clerk',
#  'Plan Review Spec 3': 'Plan Review Spec 3',
#  'Plan Review Specialist Iii': 'Plan Review Specialist Iii',
#  'Supervising Plan Review Specialist': 'Supervising Plan Review Specialist',
#  'Equipment Mechanic': 'Equipment Mechanic',
#  'Equip Mech': 'Equip Mech',
#  'Supv Department HR Anlyst': 'Supv Department Hr Anlyst',
#  'Administrative Aide 2': 'Administrative Aide 2',
#  'Librarian IV': 'Librarian Iv',
#  'Haz Mat Inspector III (Solid Waste Inspector  III)': 'Haz Mat Inspector Iii (Solid Waste Inspector  Iii)',
#  'Haz Mat Inspctr 3(Solid Wst Insp 3)': 'Haz Mat Inspctr 3(Solid Wst Insp 3)',
#  'Hourly/Lifeguard': 'Hourly/Lifeguard',
#  'FIRE CAPTAIN': 'Fire Captain',
#  'FIRE ENGINEER': 'Fire Engineer',
#  'Police Services Officer': 'Police Services Officer',
#  'H/Sr Recreation Leader': 'H/Sr Recreation Leader',
#  'Management Analyst I': 'Management Analyst I',
#  'Senior Office Specialist': 'Senior Office Specialist',
#  'Custodian II': 'Custodian Ii',
#  'Custodian 2': 'Custodian 2',
#  'Fire Recruit': 'Fire Recruit',
#  'Fire Fighter 2': 'Fire Fighter 2',
#  'Building Supervisor': 'Building Supervisor',
#  'Bldg Maint Supv': 'Bldg Maint Supv',
#  'Building Maintenance Supervisor': 'Building Maintenance Supervisor',
#  'Customer Services Field Worker': 'Customer Services Field Worker',
#  'Sanitation  Supervisor': 'Sanitation  Supervisor',
#  'Water Utilities Plant Electrician I': 'Water Utilities Plant Electrician I',
#  'Water Utilities Plant Electrician Ii': 'Water Utilities Plant Electrician Ii',
#  'Development Project Manager Iii': 'Development Project Manager Iii',
#  'Crossing Guard': 'Crossing Guard',
#  'Utility Worker I': 'Utility Worker I',
#  'Business Systems Spec': 'Business Systems Spec',
#  'Business Systems Specialist': 'Business Systems Specialist',
#  'Fire Battalion Chief': 'Fire Battalion Chief',
#  'Hourly/Sr Recreation Leader': 'Hourly/Sr Recreation Leader',
#  'Court Support Clerk I': 'Court Support Clerk I',
#  'Court Support Clrk 1': 'Court Support Clrk 1',
#  'Emergency Medical Technician': 'Emergency Medical Technician',
#  'Instructor/WSI': 'Instructor/Wsi',
#  'Aquatics Instructor': 'Aquatics Instructor',
#  'Council Rep 1': 'Council Rep 1',
#  'Building Inspector': 'Building Inspector',
#  'Senior Wastewater Plant Operator': 'Senior Wastewater Plant Operator',
#  'H/Recreation Aide': 'H/Recreation Aide',
#  'Jr Engineer-Civil(Student)': 'Jr Engineer-Civil(Student)',
#  'General Counsel': 'General Counsel',
#  'Purchasing Technician': 'Purchasing Technician',
#  'Senior Purchasing Technician': 'Senior Purchasing Technician',
#  'Fire Fighter Iii': 'Fire Fighter Iii',
#  'Police Cadet': 'Police Cadet',
#  'Beach Safety Officer': 'Beach Safety Officer',
#  'Librarian Ii': 'Librarian Ii',
#  'Court Support Clrk 2': 'Court Support Clrk 2',
#  'Utility Worker II': 'Utility Worker Ii',
#  'Utility Worker 2': 'Utility Worker 2',
#  'Word Processing Operator': 'Word Processing Operator',
#  'Office Support Specialist': 'Office Support Specialist',
#  'POLICE AGENT': 'Police Agent',
#  'POLICE SERGEANT': 'Police Sergeant',
#  'Police Lieutenant': 'Police Lieutenant',
#  'Administrative Aide II': 'Administrative Aide Ii',
#  'Biologist 3(Environ Biolgist)': 'Biologist 3(Environ Biolgist)',
#  'INTERN, GRADUATE': 'Intern, Graduate',
#  'Intern - Graduate': 'Intern - Graduate',
#  'Fire Fighter II': 'Fire Fighter Ii',
#  'PRINCIPAL CIVIL ENGINEER': 'Principal Civil Engineer',
#  'Project Officer II (Prin Wtr ReSeniorc Specialist)': 'Project Officer Ii (Prin Wtr Reseniorc Specialist)',
#  'Project Ofcr 2(Prin Wtr Resrc Spec)': 'Project Ofcr 2(Prin Wtr Resrc Spec)',
#  'Maintenance Worker I': 'Maintenance Worker I',
#  'Mechanical Technologist I': 'Mechanical Technologist I',
#  'Field Rep': 'Field Rep',
#  'Police Officer Trainee': 'Police Officer Trainee',
#  'Park Ranger Aide': 'Park Ranger Aide',
#  'Senior Park Ranger': 'Senior Park Ranger',
#  'Part Time Misc': 'Part Time Misc',
#  'Sr Budget Dev Anlyst': 'Sr Budget Dev Anlyst',
#  'Finance Analyst 3': 'Finance Analyst 3',
#  'Finance Analyst Iii': 'Finance Analyst Iii',
#  'Lifeguard 2': 'Lifeguard 2',
#  'Senior Backflow & Cross Connection Specialist': 'Senior Backflow & Cross Connection Specialist',
#  'Emt (Non-Safety)': 'Emt (Non-Safety)',
#  'FISCAL OFFICE SPECIALIST': 'Fiscal Office Specialist',
#  'SR OFFICE SPECIALIST': 'Sr Office Specialist',
#  'SR FISCAL OFFICE SPECIALIST': 'Sr Fiscal Office Specialist',
#  'Senior Fiscal Office Specialst': 'Senior Fiscal Office Specialst',
#  'Library Assistant 1': 'Library Assistant 1',
#  'Plant Tech Supv': 'Plant Tech Supv',
#  'Plant Procs Cntrl Supv(Plnt Maint Coord)': 'Plant Procs Cntrl Supv(Plnt Maint Coord)',
#  'Beach/Parks Maintenance Worker': 'Beach/Parks Maintenance Worker',
#  'Supervisor II (Recreation)': 'Supervisor Ii (Recreation)',
#  'Supervisor III (Recreation)': 'Supervisor Iii (Recreation)',
#  'Supervisor III (Comm Svs)': 'Supervisor Iii (Comm Svs)',
#  'Seasonal Worker Ii - Parking Enforcement': 'Seasonal Worker Ii - Parking Enforcement',
#  'Development Project Manager Ii': 'Development Project Manager Ii',
#  'Public Art Program Administrator': 'Public Art Program Administrator',
#  'Human Resources Assistant': 'Human Resources Assistant',
#  'Sanitation Systems Oper. II': 'Sanitation Systems Oper. Ii',
#  'Sanitation Systems Oper. Ii': 'Sanitation Systems Oper. Ii',
#  'Recreation Leader Ii': 'Recreation Leader Ii',
#  'Recreation  Leader I': 'Recreation  Leader I',
#  'Recreation Leader (PT)': 'Recreation Leader (Pt)',
#  'Recreation Leader (Pt)': 'Recreation Leader (Pt)',
#  'Intern': 'Intern',
#  'Utility Worker 1': 'Utility Worker 1',
#  'PEACE OFFICER': 'Peace Officer',
#  'Recreation  Aide': 'Recreation  Aide',
#  'Motor Sweeper Oper': 'Motor Sweeper Oper',
#  'Motor Sweeper Operator': 'Motor Sweeper Operator',
#  'Clerical Assistant I': 'Clerical Assistant I',
#  'Cashier': 'Cashier',
#  'Maintenance Technician I': 'Maintenance Technician I',
#  'Lead Maintenance Technician': 'Lead Maintenance Technician',
#  'LEGAL ASSISTANT': 'Legal Assistant',
#  'Legal Assistant': 'Legal Assistant',
#  'Senior  Office  Assistant': 'Senior  Office  Assistant',
#  'Administrative Secretary': 'Administrative Secretary',
#  'Water Sys Tech Supv': 'Water Sys Tech Supv',
#  'Water Systems Technician Supervisor': 'Water Systems Technician Supervisor',
#  'Auto Messenger 1': 'Auto Messenger 1',
#  'Police Captain': 'Police Captain',
#  'RECREATION SPECIALIST': 'Recreation Specialist',
#  'Communications Coordinator': 'Communications Coordinator',
#  'Land Survyng Assist': 'Land Survyng Assist',
#  'Land Survyng Asoc': 'Land Survyng Asoc',
#  'Senior Recreation Leader': 'Senior Recreation Leader',
#  'BUDGET & ANALYSIS MANAGER': 'Budget & Analysis Manager',
#  'ASST DIR OF FINANCE': 'Asst Dir Of Finance',
#  'Assistant Dir Of Public Works': 'Assistant Dir Of Public Works',
#  'Rec Specialist I': 'Rec Specialist I',
#  'Contract Day Camp Counselor': 'Contract Day Camp Counselor',
#  'Stadium Maintenance Technician': 'Stadium Maintenance Technician',
#  'Stadium Maintenance Tech': 'Stadium Maintenance Tech',
#  'Equipment Technician Ii': 'Equipment Technician Ii',
#  'Aquatics Technician I': 'Aquatics Technician I',
#  'Aquatics Technician Ii': 'Aquatics Technician Ii',
#  'Accounting Clerk': 'Accounting Clerk',
#  'ACCOUNTING TECHNICIAN': 'Accounting Technician',
#  'Accounting Technician Ii': 'Accounting Technician Ii',
#  'Animal Care Specialist': 'Animal Care Specialist',
#  'Accounting Technician Ii (T)': 'Accounting Technician Ii (T)',
#  'Water Utility Worker': 'Water Utility Worker',
#  'Rec Leader': 'Rec Leader',
#  'Economic Develp Specialist': 'Economic Develp Specialist',
#  'Dept Spec/Dept Aide': 'Dept Spec/Dept Aide',
#  'Water Utilities Crew Leader': 'Water Utilities Crew Leader',
#  'Utility Systems Mechanic': 'Utility Systems Mechanic',
#  'Literacy Tutor/Learner Coordinator': 'Literacy Tutor/Learner Coordinator',
#  'Plant Technician I': 'Plant Technician I',
#  'Junior Planner': 'Junior Planner',
#  'Custodian 1': 'Custodian 1',
#  'Sr Engineering Aide': 'Sr Engineering Aide',
#  'Utility Worker Ii': 'Utility Worker Ii',
#  'Swimming Pool Mgr 1': 'Swimming Pool Mgr 1',
#  'Swimming Pool Manager I': 'Swimming Pool Manager I',
#  'School Crossing Guard': 'School Crossing Guard',
#  'Heavy Truck Driver Ii': 'Heavy Truck Driver Ii',
#  'Golf Course Greenskeeper': 'Golf Course Greenskeeper',
#  'Office Specialist': 'Office Specialist',
#  'Recreation Coordinator': 'Recreation Coordinator',
#  'Recreation Leader IV': 'Recreation Leader Iv',
#  'LIBRARY ASSOCIATE': 'Library Associate',
#  'Library Associate': 'Library Associate',
#  'Librarian': 'Librarian',
#  'BEACH/PARKS MAINTENANCE WORKER': 'Beach/Parks Maintenance Worker',
#  'Recreation Leader II (Therap Recreation)': 'Recreation Leader Ii (Therap Recreation)',
#  'Supv Rec Spec': 'Supv Rec Spec',
#  'Supervising Recreation Specialist': 'Supervising Recreation Specialist',
#  'Trainer': 'Trainer',
#  'Associate Personnel Analyst': 'Associate Personnel Analyst',
#  'NETWORK SYSTEMS TECHNICIAN': 'Network Systems Technician',
#  'Public Works Maintenance Worker': 'Public Works Maintenance Worker',
#  'PUBLICWORKSMAINTENANCEWKR': 'Publicworksmaintenancewkr',
#  'Public Works Maintenance Wkr': 'Public Works Maintenance Wkr',
#  'COUNCILPERSON': 'Councilperson',
#  'Councilperson': 'Councilperson',
#  'Fire Fighter I': 'Fire Fighter I',
#  'Custodian': 'Custodian',
#  'Performance Auditor': 'Performance Auditor',
#  'Division Coordinator': 'Division Coordinator',
#  'H/Maintenance Assistant': 'H/Maintenance Assistant',
#  'Council Member': 'Council Member',
#  'Planning Commissioner': 'Planning Commissioner',
#  'CODE ENF OFFCR II': 'Code Enf Offcr Ii',
#  'Code Enforcement Officer Ii': 'Code Enforcement Officer Ii',
#  'Senior Code Enforcemnt Officer': 'Senior Code Enforcemnt Officer',
#  'Seasonal Maintenance Assistant Ii': 'Seasonal Maintenance Assistant Ii',
#  'PUBLICWORKSINSPECTOR': 'Publicworksinspector',
#  'Field Engineering Inspector I': 'Field Engineering Inspector I',
#  'Community Development Specialist Iv': 'Community Development Specialist Iv',
#  'Payroll Spec 2': 'Payroll Spec 2',
#  'Payroll Specialist Ii': 'Payroll Specialist Ii',
#  'Admin Secretary 1': 'Admin Secretary 1',
#  'Deputy City Clerk': 'Deputy City Clerk',
#  'City Clerk': 'City Clerk',
#  'Community Development Spec II': 'Community Development Spec Ii',
#  'Community Development Manager': 'Community Development Manager',
#  'Community  Development  Manager': 'Community  Development  Manager',
#  'Dir Of Housing & Economic Dev': 'Dir Of Housing & Economic Dev',
#  'BEACH MAINTENANCE WORKER': 'Beach Maintenance Worker',
#  'Beach Maintenance Worker': 'Beach Maintenance Worker',
#  'Structural Inspector II': 'Structural Inspector Ii',
#  'Structural Inspector 2': 'Structural Inspector 2',
#  'Structural Inspector Ii': 'Structural Inspector Ii',
#  'Dispatcher 1': 'Dispatcher 1',
#  'Public Works Dispatcher': 'Public Works Dispatcher',
#  'Dispatcher I': 'Dispatcher I',
#  'MAINTENANCE WORKER': 'Maintenance Worker',
#  'Building Service Technician': 'Building Service Technician',
#  'Gardener (Seasonal)': 'Gardener (Seasonal)',
#  'Grounds Maintenance Worker I': 'Grounds Maintenance Worker I',
#  'City Councilmember': 'City Councilmember',
#  'Office Specialist I, Ii': 'Office Specialist I, Ii',
#  'Office Specialist I - Ii': 'Office Specialist I - Ii',
#  'Firefighter': 'Firefighter',
#  'Instrumentation & Control Technician Trainee': 'Instrumentation & Control Technician Trainee',
#  'Jr. Lifeguard': 'Jr. Lifeguard',
#  'Public Works Maintenance Crew Leader': 'Public Works Maintenance Crew Leader',
#  'Pw Maint Crew Leader': 'Pw Maint Crew Leader',
#  'Commissioner': 'Commissioner',
#  'Park Attendant I': 'Park Attendant I',
#  'Recreation Cntr Director I': 'Recreation Cntr Director I',
#  'Area Manager 2': 'Area Manager 2',
#  'Rec Aide': 'Rec Aide',
#  'Clerical Assistant II': 'Clerical Assistant Ii',
#  'Wastewater Pretreatment Inspector III': 'Wastewater Pretreatment Inspector Iii',
#  'Wstwtr Pretrmt Inspctr 3': 'Wstwtr Pretrmt Inspctr 3',
#  'Wastewater Pretreatment Inspector Iii': 'Wastewater Pretreatment Inspector Iii',
#  'Dock Attendant': 'Dock Attendant',
#  'Senior Engineer': 'Senior Engineer',
#  'Lifeguard': 'Lifeguard',
#  'BUILDING INSPECTOR III': 'Building Inspector Iii',
#  'Senior Building Inspector': 'Senior Building Inspector',
#  'Clerical Asst 2(Temp Pool)': 'Clerical Asst 2(Temp Pool)',
#  'Capital Projects Manager': 'Capital Projects Manager',
#  'Hourly/Maintenance Assistant': 'Hourly/Maintenance Assistant',
#  'Principal Librarian': 'Principal Librarian',
#  'Hourly/Reference Librarian': 'Hourly/Reference Librarian',
#  'H/Professional': 'H/Professional',
#  'Water Sys Tech 1': 'Water Sys Tech 1',
#  'Water Sys Tech 2': 'Water Sys Tech 2',
#  'Accountant II': 'Accountant Ii',
#  'Accountant 2': 'Accountant 2',
#  'Finance Analyst Ii': 'Finance Analyst Ii',
#  'Associate Management Analyst (Retire Functional Specialist II)': 'Associate Management Analyst (Retire Functional Specialist Ii)',
#  'Asoc Mgmt Anlyst(Ret Fncl Spec 2)': 'Asoc Mgmt Anlyst(Ret Fncl Spec 2)',
#  'Retirement Financial Specialist Ii': 'Retirement Financial Specialist Ii',
#  'Customer Service Rep Ii': 'Customer Service Rep Ii',
#  'Student Intern-Mayor/Council': 'Student Intern-Mayor/Council',
#  'Beach Lifeguard': 'Beach Lifeguard',
#  'Municipal Projects Manager': 'Municipal Projects Manager',
#  'Forensic Evidence Tech': 'Forensic Evidence Tech',
#  'Dispatcher Ii': 'Dispatcher Ii',
#  'Engineering Manager': 'Engineering Manager',
#  'Custodian I': 'Custodian I',
#  'Community Service Officer': 'Community Service Officer',
#  'REC LEADER': 'Rec Leader',
#  'Heavy Truck Drvr 1': 'Heavy Truck Drvr 1',
#  'Sewer Maintenance Equipment Operator': 'Sewer Maintenance Equipment Operator',
#  'Lifeguard Ii': 'Lifeguard Ii',
#  'Compliance & Metering Manager': 'Compliance & Metering Manager',
#  'Compliance & Metering Mgr': 'Compliance & Metering Mgr',
#  'Fire Dispatch Supervisor': 'Fire Dispatch Supervisor',
#  'Fire Dispatch Supv': 'Fire Dispatch Supv',
#  'Fire Dispatcher': 'Fire Dispatcher',
#  'Legal Secretary II': 'Legal Secretary Ii',
#  'Asst Cty Manager': 'Asst Cty Manager',
#  'Assistant City Manager': 'Assistant City Manager',
#  'Asst City Manager': 'Asst City Manager',
#  'Plan Review Specialist I': 'Plan Review Specialist I',
#  'Assistant Engineer-Civil': 'Assistant Engineer-Civil',
#  'Electrical Inspector 1': 'Electrical Inspector 1',
#  'Electrical Inspector 2': 'Electrical Inspector 2',
#  'Electrical Inspector Ii': 'Electrical Inspector Ii',
#  'Seasonal Maintenance Assistant I': 'Seasonal Maintenance Assistant I',
#  'Zoning Investigator 2': 'Zoning Investigator 2',
#  'Zoning Investigator Ii': 'Zoning Investigator Ii',
#  'Senior Zoning Investigator': 'Senior Zoning Investigator',
#  'LTD Termed Participant': 'Ltd Termed Participant',
#  'Associate Budget Development Analyst': 'Associate Budget Development Analyst',
#  'Administrative Assistant III': 'Administrative Assistant Iii',
#  'Senior Administrative Assistant': 'Senior Administrative Assistant',
#  'Cmnty Dev Spec 1': 'Cmnty Dev Spec 1',
#  'Cmnty Dev Spec 2': 'Cmnty Dev Spec 2',
#  'Cmnty Dev Spec 4': 'Cmnty Dev Spec 4',
#  'Community Development Coordinator': 'Community Development Coordinator',
#  'Field Evidence Technician': 'Field Evidence Technician',
#  'Plant Systems Technician Ii': 'Plant Systems Technician Ii',
#  'Administrative Aide 1': 'Administrative Aide 1',
#  'Accountant Trainee': 'Accountant Trainee',
#  'Accountant 1': 'Accountant 1',
#  'Payroll Spec 1': 'Payroll Spec 1',
#  'H/Library Clerk': 'H/Library Clerk',
#  'H/Library Technician': 'H/Library Technician',
#  'Asst Reservoir Keeper': 'Asst Reservoir Keeper',
#  'Management Intern-Mayor/Council': 'Management Intern-Mayor/Council',
#  'Information Systems Analyst Iv': 'Information Systems Analyst Iv',
#  'Lifeguard Sergeant': 'Lifeguard Sergeant',
#  'Associate Engineer': 'Associate Engineer',
#  'City Traffic Engineer': 'City Traffic Engineer',
#  'Asoc Eng-Traffic': 'Asoc Eng-Traffic',
#  'LIBRARY ASSOCIATE (HRLY)': 'Library Associate (Hrly)',
#  'LIBRARIAN I (HRLY)': 'Librarian I (Hrly)',
#  'Department Assistant': 'Department Assistant',
#  'Wastewater Collections Tech I': 'Wastewater Collections Tech I',
#  'Wastewater Collections Tech Ii': 'Wastewater Collections Tech Ii',
#  'Building Inspector Ii': 'Building Inspector Ii',
#  'Bldg Inspector Ii': 'Bldg Inspector Ii',
#  'Sanitation Driver II': 'Sanitation Driver Ii',
#  'Sanitation Driver 2': 'Sanitation Driver 2',
#  'Sanitation Driver 3': 'Sanitation Driver 3',
#  'Area Refuse Collect Supv': 'Area Refuse Collect Supv',
#  'Area Refuse Collections Supervisor': 'Area Refuse Collections Supervisor',
#  'Hourly/Recreation Aide': 'Hourly/Recreation Aide',
#  'H/Preschool Instructor': 'H/Preschool Instructor',
#  'Hourly/Preschool Instructor': 'Hourly/Preschool Instructor',
#  'Assistant To The City Manager': 'Assistant To The City Manager',
#  'Assistant Police Chief': 'Assistant Police Chief',
#  'Fire Battalion Chief - A': 'Fire Battalion Chief - A',
#  'Maintenance & Oper Coordinator': 'Maintenance & Oper Coordinator',
#  'Administrative Coordinator': 'Administrative Coordinator',
#  'Firefighter Paramedic (56 Hour)': 'Firefighter Paramedic (56 Hour)',
#  'Fire Engineer (56 Hour)': 'Fire Engineer (56 Hour)',
#  'Fire Captain (56 Hour)': 'Fire Captain (56 Hour)',
#  'Customer Services Technician II': 'Customer Services Technician Ii',
#  'Wastewater Trtmt Plant Oit': 'Wastewater Trtmt Plant Oit',
#  'Human Resources Analyst': 'Human Resources Analyst',
#  'Pool Guard I': 'Pool Guard I',
#  'Wastewater Utility Worker II': 'Wastewater Utility Worker Ii',
#  'Business Systems Associate - Uf': 'Business Systems Associate - Uf',
#  'Business Systems Associate': 'Business Systems Associate',
#  'Utilities Asset Management Program Specialist': 'Utilities Asset Management Program Specialist',
#  'Library Assistant I': 'Library Assistant I',
#  'Equipment Operator I (Sewer Maintenance Equipment Operator)': 'Equipment Operator I (Sewer Maintenance Equipment Operator)',
#  'Equip Oper 1(Sewer Maint Equip Oper)': 'Equip Oper 1(Sewer Maint Equip Oper)',
#  'Budget/Legislative Analyst I': 'Budget/Legislative Analyst I',
#  'Court Support Clerk Ii': 'Court Support Clerk Ii',
#  'Power Plant Operator': 'Power Plant Operator',
#  'Parks Maintenance Worker I': 'Parks Maintenance Worker I',
#  'Recreation Leader (Ft)': 'Recreation Leader (Ft)',
#  'Clerical Asst I Temporary': 'Clerical Asst I Temporary',
#  'Hourly/Library Clerk': 'Hourly/Library Clerk',
#  'Library  Assistant': 'Library  Assistant',
#  'Plant Process Control Electrician': 'Plant Process Control Electrician',
#  'Seasonal Lifeguard Pool': 'Seasonal Lifeguard Pool',
#  'UTILITY & MTC TECH II': 'Utility & Mtc Tech Ii',
#  'Front Of House Assistant': 'Front Of House Assistant',
#  'Auto Messenger II': 'Auto Messenger Ii',
#  'Hourly/Library Technician': 'Hourly/Library Technician',
#  'Deputy City Attorney Ii': 'Deputy City Attorney Ii',
#  'Assistant Management Analyst': 'Assistant Management Analyst',
#  'Utility Worker Trainee': 'Utility Worker Trainee',
#  'Principal Clerk': 'Principal Clerk',
#  'Traffic Signal Technician II': 'Traffic Signal Technician Ii',
#  'Traffic Signal Technician 2': 'Traffic Signal Technician 2',
#  'Traffic Signal Supervisor': 'Traffic Signal Supervisor',
#  'Fire Fighter/Pm A,B,C': 'Fire Fighter/Pm A,B,C',
#  'Beach Lifeguard I': 'Beach Lifeguard I',
#  'Structural Engrng Asoc': 'Structural Engrng Asoc',
#  'Planning Technician Ii': 'Planning Technician Ii',
#  'Construction Maintenance Worker I': 'Construction Maintenance Worker I',
#  'Water Utilities Worker I': 'Water Utilities Worker I',
#  'Facility Attendant': 'Facility Attendant',
#  'PRINCIPAL MANAGEMENT ANALYST': 'Principal Management Analyst',
#  'POLICE ADMIN SVCS ADMINISTRATO': 'Police Admin Svcs Administrato',
#  'Police Admin Srvcs Admnstrtr': 'Police Admin Srvcs Admnstrtr',
#  'Police Admin Svcs Administratr': 'Police Admin Svcs Administratr',
#  'Fire Inspector': 'Fire Inspector',
#  'Fire Prevention Inspector II/Civil': 'Fire Prevention Inspector Ii/Civil',
#  'Fire Prevention Supv/Civ': 'Fire Prevention Supv/Civ',
#  'Fire Prevention Supervisor': 'Fire Prevention Supervisor',
#  'H/Admin. Assistant': 'H/Admin. Assistant',
#  'Hourly/Admin. Assistant': 'Hourly/Admin. Assistant',
#  'H/Rec Program/Services Coord': 'H/Rec Program/Services Coord',
#  'Hourly/Rec Prog/Services Coord': 'Hourly/Rec Prog/Services Coord',
#  'Plant Systems Technician II': 'Plant Systems Technician Ii',
#  'Property  Agent': 'Property  Agent',
#  'Property Agent': 'Property Agent',
#  'Environmental Specialist I': 'Environmental Specialist I',
#  'Code Compliance Officer': 'Code Compliance Officer',
#  'Park Maintenance Worker I': 'Park Maintenance Worker I',
#  'PARK MTCE WORKER I': 'Park Mtce Worker I',
#  'Park Mtce Worker I': 'Park Mtce Worker I',
#  'Confidential Secretary to Police Chief': 'Confidential Secretary To Police Chief',
#  'Conf Secretary to Police Chief': 'Conf Secretary To Police Chief',
#  'Building Service Supervisor': 'Building Service Supervisor',
#  'Bldg Service Supv': 'Bldg Service Supv',
#  'CITY COUNCILMEMBER': 'City Councilmember',
#  'Principal Engineer': 'Principal Engineer',
#  'Sewer Engineering Division Manager': 'Sewer Engineering Division Manager',
#  'Sewer Engineering Divison Man': 'Sewer Engineering Divison Man',
#  'Sewer Engineering Division Man': 'Sewer Engineering Division Man',
#  'INTERN/STUDENT WORKER I': 'Intern/Student Worker I',
#  'Fire Battalion Chief-56 Hr': 'Fire Battalion Chief-56 Hr',
#  'Firefighter 2.5%': 'Firefighter 2.5%',
#  'H/Aquatics Instructor': 'H/Aquatics Instructor',
#  'Wastewater Operations Supervisor': 'Wastewater Operations Supervisor',
#  'Wstwtr Operations Supv': 'Wstwtr Operations Supv',
#  'Wastewater Maintenance Worker III': 'Wastewater Maintenance Worker Iii',
#  'WSTEWTR MTC WRKR III': 'Wstewtr Mtc Wrkr Iii',
#  'Wstewtr Mtc Wrkr Iii': 'Wstewtr Mtc Wrkr Iii',
#  'Collections Investigator I': 'Collections Investigator I',
#  'Carpenter': 'Carpenter',
#  'Hourly/Recreation Leader': 'Hourly/Recreation Leader',
#  'Test Administration Specialist': 'Test Administration Specialist',
#  'Test Administration Spec': 'Test Administration Spec',
#  'Sr Test Admin Spec': 'Sr Test Admin Spec',
#  'Personnel Assistant 2': 'Personnel Assistant 2',
#  'Supervising Department Human Resources Analyst': 'Supervising Department Human Resources Analyst',
#  'Senior Planner': 'Senior Planner',
#  'Info Sys Anlyst 4': 'Info Sys Anlyst 4',
#  'Assistant Chemist': 'Assistant Chemist',
#  'Asst Chemist': 'Asst Chemist',
#  'MSW': 'Msw',
#  'Facilities Technician': 'Facilities Technician',
#  'Facilities Technician Ii': 'Facilities Technician Ii',
#  'Facilities Supervisor': 'Facilities Supervisor',
#  'Seasonal Parking Enforc.  Ii': 'Seasonal Parking Enforc.  Ii',
#  'Seasonal Assistant II': 'Seasonal Assistant Ii',
#  'Senior Chemist': 'Senior Chemist',
#  'Parking Enfrc Ofcr 1': 'Parking Enfrc Ofcr 1',
#  'Biologist II': 'Biologist Ii',
#  'Biologist 2': 'Biologist 2',
#  'Maintenance Technician Ii': 'Maintenance Technician Ii',
#  'Associate Engineer - Traffic': 'Associate Engineer - Traffic',
#  'Accountant IV': 'Accountant Iv',
#  'Accountant 4': 'Accountant 4',
#  'Finance Analyst 4': 'Finance Analyst 4',
#  'Finance Analyst Iv': 'Finance Analyst Iv',
#  'Public Information Specialist': 'Public Information Specialist',
#  'Public Info Spec': 'Public Info Spec',
#  'Information Systems Analyst III': 'Information Systems Analyst Iii',
#  'LIFEGUARD/INSTRUCTOR': 'Lifeguard/Instructor',
#  'Fire Division Chief': 'Fire Division Chief',
#  'Fire Battalion Chief-112 Hours': 'Fire Battalion Chief-112 Hours',
#  'Construction Manager': 'Construction Manager',
#  'Lifeguard Assistant': 'Lifeguard Assistant',
#  'Communications Supervisor': 'Communications Supervisor',
#  'H/Office Assistant': 'H/Office Assistant',
#  'Area Manager II': 'Area Manager Ii',
#  'Police Property And Evidence Specialist': 'Police Property And Evidence Specialist',
#  'Police Records Specialist': 'Police Records Specialist',
#  'H/Technical Assistant': 'H/Technical Assistant',
#  'Hourly/Technical Assistant': 'Hourly/Technical Assistant',
#  'Caretaker': 'Caretaker',
#  'Legal Secretary 2': 'Legal Secretary 2',
#  'Library Volunteer Coordinator': 'Library Volunteer Coordinator',
#  'Golf Starter': 'Golf Starter',
#  'Golf Operations Assistant': 'Golf Operations Assistant',
#  'Environmental Biologist 3': 'Environmental Biologist 3',
#  'Environmental Biologist Iii': 'Environmental Biologist Iii',
#  'Pool Guard Ii': 'Pool Guard Ii',
#  'Park & Trail Ranger': 'Park & Trail Ranger',
#  'Police Invstgtv Serv Ofcr 1': 'Police Invstgtv Serv Ofcr 1',
#  'Fire Prevention Inspctr 2': 'Fire Prevention Inspctr 2',
#  'Food Services Supervisor': 'Food Services Supervisor',
#  'Sr Park Ranger': 'Sr Park Ranger',
#  'Environmental Biologist 2': 'Environmental Biologist 2',
#  'Environmental Biologist Ii': 'Environmental Biologist Ii',
#  'Senior Locksmith': 'Senior Locksmith',
#  'Sr Locksmith': 'Sr Locksmith',
#  'Paralegal': 'Paralegal',
#  'Administrative Assistant': 'Administrative Assistant',
#  'Office Specialist Ill': 'Office Specialist Ill',
#  'OFFICESPECIALISTII': 'Officespecialistii',
#  'Office Specialist II': 'Office Specialist Ii',
#  'Ocean Lifeguard I': 'Ocean Lifeguard I',
#  'H/Arts Aide': 'H/Arts Aide',
#  'Collections Officer': 'Collections Officer',
#  'Payroll Technician II': 'Payroll Technician Ii',
#  'Payroll Technician Ii': 'Payroll Technician Ii',
#  'ACCOUNTCLERK': 'Accountclerk',
#  'Hourly/Emergency Medical Technician': 'Hourly/Emergency Medical Technician',
#  'Fire Captain-56 Hr': 'Fire Captain-56 Hr',
#  'Senior Budget Development Analyst': 'Senior Budget Development Analyst',
#  'Recreation Specialist 11': 'Recreation Specialist 11',
#  'Rec Specialist': 'Rec Specialist',
#  'Deputy Fire Chief': 'Deputy Fire Chief',
#  'Fire Prevention Inspector Ii': 'Fire Prevention Inspector Ii',
#  'Heavy Truck Driver I': 'Heavy Truck Driver I',
#  'Firefighter w/ PM Bonus': 'Firefighter W/ Pm Bonus',
#  'FIRE ENGINEER - PM CERT': 'Fire Engineer - Pm Cert',
#  'Fire Captain - Pm Cert': 'Fire Captain - Pm Cert',
#  'Contract Ocean Lifeguard II': 'Contract Ocean Lifeguard Ii',
#  'CONTRACT OCEAN LIFEGUARD II': 'Contract Ocean Lifeguard Ii',
#  'Contract Ocean Lifeguard Ii': 'Contract Ocean Lifeguard Ii',
#  'Firefighter/Paramedic Iii': 'Firefighter/Paramedic Iii',
#  'Firefighter/Paramedic I': 'Firefighter/Paramedic I',
#  'Paramedic (Non-Safety)': 'Paramedic (Non-Safety)',
#  'TREASURY MANAGER': 'Treasury Manager',
#  'TREASURY AND BUSINESS MANAGER': 'Treasury And Business Manager',
#  'ASST DIR OF DEV SVCS (INTERIM)': 'Asst Dir Of Dev Svcs (Interim)',
#  'ASSISTANT DIR DEVELOPMENT SVCS': 'Assistant Dir Development Svcs',
#  'Assistant Dir Of Devlpmnt Svcs': 'Assistant Dir Of Devlpmnt Svcs',
#  'Director Of Development Servic': 'Director Of Development Servic',
#  'Dir. Of Development Services': 'Dir. Of Development Services',
#  'Deputy City Manager': 'Deputy City Manager',
#  'Sr Mgmt Anlyst(Hland Secur Coord)': 'Sr Mgmt Anlyst(Hland Secur Coord)',
#  'Contract Recreation Services Assistant': 'Contract Recreation Services Assistant',
#  'EMS Paramed Nurse Coordinator': 'Ems Paramed Nurse Coordinator',
#  'Ems Paramed Nurse Coordinator': 'Ems Paramed Nurse Coordinator',
#  'Principal Auditor': 'Principal Auditor',
#  'Commctn Tech': 'Commctn Tech',
#  'Communications Technician': 'Communications Technician',
#  'LIFEGUARD I': 'Lifeguard I',
#  'Program Specialist': 'Program Specialist',
#  'Heavy Truck Drvr 2': 'Heavy Truck Drvr 2',
#  'COMMISSIONERS': 'Commissioners',
#  'Commissioners': 'Commissioners',
#  'Police Officer 5%': 'Police Officer 5%',
#  'Police Offier': 'Police Offier',
#  'Comm. Operator II': 'Comm. Operator Ii',
#  'Comm. Operator Ii': 'Comm. Operator Ii',
#  'Firefighter Paramedic Recruit (56 Hour)': 'Firefighter Paramedic Recruit (56 Hour)',
#  'Community Srvs Officer': 'Community Srvs Officer',
#  'PUMP MAINT TECHNICIAN': 'Pump Maint Technician',
#  'Pump Maintenance Technician': 'Pump Maintenance Technician',
#  'Pump Maintenance Supervisor': 'Pump Maintenance Supervisor',
#  'FINANCE ANALYST I': 'Finance Analyst I',
#  'FINANCE ANALYST II': 'Finance Analyst Ii',
#  'FINANCE ANALYST III': 'Finance Analyst Iii',
#  'Finance Manager I': 'Finance Manager I',
#  'Plan Review Specialist Iv': 'Plan Review Specialist Iv',
#  'Clerical Assistant II (Temporary Pool)': 'Clerical Assistant Ii (Temporary Pool)',
#  'Criminalist 2': 'Criminalist 2',
#  'Criminalist Ii': 'Criminalist Ii',
#  'Gis Technician': 'Gis Technician',
#  'Senior Drafting Aide': 'Senior Drafting Aide',
#  'Police Service Officer I': 'Police Service Officer I',
#  'Fleet Assistant': 'Fleet Assistant',
#  'Principal Traffic Engineering Aide': 'Principal Traffic Engineering Aide',
#  'Principal Traffic Engrng Aide': 'Principal Traffic Engrng Aide',
#  'Master Fleet Technician': 'Master Fleet Technician',
#  'H/Library Page': 'H/Library Page',
#  'Hourly/Library Page': 'Hourly/Library Page',
#  'Deputy City Clerk 1': 'Deputy City Clerk 1',
#  'Deputy City Clerk I': 'Deputy City Clerk I',
#  'Revenue Manager': 'Revenue Manager',
#  'Assistant Recreation Services Supervisor': 'Assistant Recreation Services Supervisor',
#  'Asst Rec Services Supv': 'Asst Rec Services Supv',
#  'Recreation Services Supv': 'Recreation Services Supv',
#  'Recreation Services Manager': 'Recreation Services Manager',
#  'Recreation Services Mgr': 'Recreation Services Mgr',
#  'Parks And Rec Manager': 'Parks And Rec Manager',
#  'Parks And Recreation Manager': 'Parks And Recreation Manager',
#  'Parks And Rec Mgr': 'Parks And Rec Mgr',
#  'Streets Technician I': 'Streets Technician I',
#  'Hvacr Technician': 'Hvacr Technician',
#  'Claims Clerk': 'Claims Clerk',
#  'Police Property & Evid Clerk': 'Police Property & Evid Clerk',
#  'Police Property & Evid Clrk': 'Police Property & Evid Clrk',
#  'Police Property & Evid Spec': 'Police Property & Evid Spec',
#  'Police Property And Evidence Supervisor': 'Police Property And Evidence Supervisor',
#  'Wastewater Plant Operator II': 'Wastewater Plant Operator Ii',
#  'Wastewater Plant Operator III': 'Wastewater Plant Operator Iii',
#  'Wastewater Plant Supervisor': 'Wastewater Plant Supervisor',
#  'Chief Plant Operator': 'Chief Plant Operator',
#  'Sr Wstwtr Plant Operator': 'Sr Wstwtr Plant Operator',
#  'H/Sr Aquatics Instruct/Lifegrd': 'H/Sr Aquatics Instruct/Lifegrd',
#  'Hourly/Sr Aqua Instrct/Lifegrd': 'Hourly/Sr Aqua Instrct/Lifegrd',
#  'Grounds Maintenance Manager': 'Grounds Maintenance Manager',
#  'Grounds Maint Mgr': 'Grounds Maint Mgr',
#  'H/Grounds Aide': 'H/Grounds Aide',
#  'Project Officer I': 'Project Officer I',
#  'Customer Account Representative I': 'Customer Account Representative I',
#  'Customer Services Technician Ii': 'Customer Services Technician Ii',
#  'FIREFIGHTER (112 HR)': 'Firefighter (112 Hr)',
#  'FIREFIGHTER/PARAMEDIC (112 HR)': 'Firefighter/Paramedic (112 Hr)',
#  'Firefighter/Paramedic - A': 'Firefighter/Paramedic - A',
#  'Environmental Scientist Ii': 'Environmental Scientist Ii',
#  'FIREFIGHTER/PARAMEDIC': 'Firefighter/Paramedic',
#  'Fire Fighter Paramedic': 'Fire Fighter Paramedic',
#  'Hourly/Open Water Lifeguard Ii': 'Hourly/Open Water Lifeguard Ii',
#  'Recycling Spec 1': 'Recycling Spec 1',
#  'Recycling Spec 2': 'Recycling Spec 2',
#  'Pw Equipment Operator': 'Pw Equipment Operator',
#  'Police Records Technician': 'Police Records Technician',
#  'Planning  Commissioner': 'Planning  Commissioner',
#  'Mayor Representative 2': 'Mayor Representative 2',
#  'Code Compliance Ofcr': 'Code Compliance Ofcr',
#  'Code Compliance Supervisor': 'Code Compliance Supervisor',
#  'Building Inspector I': 'Building Inspector I',
#  'Bldg Inspector I': 'Bldg Inspector I',
#  'Senior Account Audit Clerk': 'Senior Account Audit Clerk',
#  'Water Utility Supv': 'Water Utility Supv',
#  'Water Utility Supervisor': 'Water Utility Supervisor',
#  'Development Project Manager I': 'Development Project Manager I',
#  'Emergency Medical Technician (Pt)': 'Emergency Medical Technician (Pt)',
#  'Senior HR Analyst': 'Senior Hr Analyst',
#  'Assistant Human Resources Manager': 'Assistant Human Resources Manager',
#  'Sr Office Specialist - Conf': 'Sr Office Specialist - Conf',
#  'Accounting Assistant': 'Accounting Assistant',
#  'Accounting  Assistant': 'Accounting  Assistant',
#  'Principal Management Analyst': 'Principal Management Analyst',
#  'Asst Mgmt Anlyst': 'Asst Mgmt Anlyst',
#  'Aquatics Technician - Pool': 'Aquatics Technician - Pool',
#  'Police Services Officer I': 'Police Services Officer I',
#  'Heavy Truck Driver II': 'Heavy Truck Driver Ii',
#  'Storm Water Inspector Ii': 'Storm Water Inspector Ii',
#  'Hourly/Grounds Aide': 'Hourly/Grounds Aide',
#  'Police Dispatch Supervisor': 'Police Dispatch Supervisor',
#  'Police Dispatch Supv': 'Police Dispatch Supv',
#  'Human Resources Technician I': 'Human Resources Technician I',
#  'Human Resources Technician Ii': 'Human Resources Technician Ii',
#  'Human Resources Specialist': 'Human Resources Specialist',
#  'Firefighter - A': 'Firefighter - A',
#  'Fire Engineer - C': 'Fire Engineer - C',
#  'Network Systems Technician': 'Network Systems Technician',
#  'Network Systems Technician Ii': 'Network Systems Technician Ii',
#  'Fire Inspector I - Temp': 'Fire Inspector I - Temp',
#  'Public Works Maint Worker': 'Public Works Maint Worker',
#  'Code Enforcement Officer II': 'Code Enforcement Officer Ii',
#  'Senior Code Enforcement Officer': 'Senior Code Enforcement Officer',
#  'Plasterer': 'Plasterer',
#  'POLICE SVCS OFFICER SUPERVISOR': 'Police Svcs Officer Supervisor',
#  'CIVILIAN BACKGROUND INVESTIGTR': 'Civilian Background Investigtr',
#  'Civilian Bckgrnd Investigator': 'Civilian Bckgrnd Investigator',
#  'Senior Distribution Operator': 'Senior Distribution Operator',
#  'Water Distribution Supervisor': 'Water Distribution Supervisor',
#  'Special Event Traffic Controller I': 'Special Event Traffic Controller I',
#  'Parking Enforcement Officer Ii': 'Parking Enforcement Officer Ii',
#  'YOUTHCOMMISSIONER': 'Youthcommissioner',
#  'Youth Commissioner': 'Youth Commissioner',
#  'BEACH LIFEGUARD II': 'Beach Lifeguard Ii',
#  'Beach Lifeguard Ii': 'Beach Lifeguard Ii',
#  'OCEAN LIFEGUARD II': 'Ocean Lifeguard Ii',
#  'Structural Inspector I': 'Structural Inspector I',
#  'INTERN, UNDERGRADUATE': 'Intern, Undergraduate',
#  'Equipment Operator II': 'Equipment Operator Ii',
#  'Equip Operator 2': 'Equip Operator 2',
#  'Maintenance Worker': 'Maintenance Worker',
#  'Equipment Operator': 'Equipment Operator',
#  'Library Intern': 'Library Intern',
#  'GARDENER I': 'Gardener I',
#  'GARDENER II': 'Gardener Ii',
#  'SR GARDENER': 'Sr Gardener',
#  'Senior Gardener': 'Senior Gardener',
#  'Senior Parks Maint Worker': 'Senior Parks Maint Worker',
#  'Tree Trimmer': 'Tree Trimmer',
#  ...}

# %%
df['Job Title'] = df['Job Title'].map(position_match_dict)

# %%
df.to_csv(f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/sdcounty_salaries_cleaned.csv", index=False)

# %%
for column in df.columns[5:-1]:
    df[f'Adjusted {column}'] = df[column] / df['Inflation Index']

df
# Out:
#         Year     Agency Employee Name        Job Title Status  Base Pay  \
# 0       2020  Escondido      6255, Gc  Police Sergeant     FT  145998.0
# 1       2020  Escondido      6255, Gc   Police Officer     FT  110080.0
# 2       2020  Escondido      6255, Gc  Police Sergeant     FT  141048.0
# 3       2020  Escondido      6255, Gc   Police Officer     FT  104113.0
# 4       2020  Escondido      6255, Gc   Police Officer     FT  111949.0
# ...      ...        ...           ...              ...    ...       ...
# 283252  2019  San Diego   Zynn, Megan     Dispatcher 2   None   49632.0
# 283253  2020  San Diego   Zynn, Megan     Dispatcher 2   None   50498.0
# 283254  2021  San Diego   Zynn, Megan    Dispatcher Ii   None   49327.0
# 283255  2022  San Diego   Zynn, Megan    Dispatcher Ii   None   58052.8
# 283256  2023  San Diego   Zynn, Megan    Dispatcher Ii   None   62009.0
#
#         Overtime Pay  Other Pay  Total Pay  Benefits  ...  Adjusted Base Pay  \
# 0           17900.00    1711.00  165609.00       NaN  ...      171885.594492
# 1           43814.00    7093.00  160987.00       NaN  ...      129598.804378
# 2            9253.00    3654.00  153955.00       NaN  ...      166057.886628
# 3           27278.00    6709.00  138100.00       NaN  ...      122573.767444
# 4           30590.00    1333.00  143872.00       NaN  ...      131799.205590
# ...              ...        ...        ...       ...  ...                ...
# 283252       3329.00   19439.00   72400.00  13780.00  ...       59153.356505
# 283253       1636.00   18401.00   70535.00  13943.00  ...       59452.038731
# 283254       2275.00   19116.00   70718.00  14511.00  ...       55467.526125
# 283255       2530.81   32610.33   93193.94  15681.86  ...       60442.515131
# 283256       5692.00   21109.00   88810.00  17473.00  ...       62009.000000
#
#         Adjusted Overtime Pay  Adjusted Other Pay  Adjusted Total Pay  \
# 0                21073.933488         2014.385486       194973.913466
# 1                51582.867142         8350.693309       189532.364830
# 2                10893.693104         4301.907987       181253.487719
# 3                32114.790932         7898.604457       162587.162833
# 4                36014.057285         1569.360522       169382.623397
# ...                       ...                 ...                 ...
# 283252            3967.632249        23168.159597        86289.148351
# 283253            1926.086882        21663.768163        83041.893776
# 283254            2558.205890        21495.676392        79521.408407
# 283255            2634.989556        33952.718292        97030.222979
# 283256            5692.000000        21109.000000        88810.000000
#
#         Adjusted Benefits  Adjusted Pension Debt  \
# 0                     NaN           39265.800542
# 1                     NaN           45478.490319
# 2                     NaN           37898.938152
# 3                     NaN           47044.318897
# 4                     NaN           44447.162624
# ...                   ...                    ...
# 283252       16423.542324                    NaN
# 283253       16415.299141                    NaN
# 283254       16317.417877               0.000000
# 283255       16327.396100           14655.442070
# 283256       17473.000000           25474.760000
#
#         Adjusted Total Pay & Benefits  Adjusted 0 annual pension debt payment  \
# 0                        48840.088812                                     NaN
# 1                        39481.672969                                     NaN
# 2                        46747.023384                                     NaN
# 3                        42339.133526                                     NaN
# 4                        37902.411230                                     NaN
# ...                               ...                                     ...
# 283252                  102712.690675                                     NaN
# 283253                   99457.192917                                     NaN
# 283254                   95838.826283                                     NaN
# 283255                  128013.061149                                     NaN
# 283256                  131757.760000                                     NaN
#
#         Adjusted Notes  Adjusted Inflation Index
# 0        283079.802820                       1.0
# 1        274492.528118                       1.0
# 2        265899.449254                       1.0
# 3        251970.615256                       1.0
# 4        251732.197252                       1.0
# ...                ...                       ...
# 283252             NaN                       1.0
# 283253             NaN                       1.0
# 283254             NaN                       1.0
# 283255             NaN                       1.0
# 283256             NaN                       1.0
#
# [283257 rows x 25 columns]

# %%
filtered_df = df[~df['Employee Name'].isin(['Provided, Not', 'Redacted'])]

# Sort by Name and Year to ensure we can track movements sequentially
filtered_df = filtered_df.sort_values(by=['Employee Name', 'Year', 'Agency'])

# List to store names that meet the criteria
selected_names = set()

# Group by Name to analyze movements and pay changes
for name, group in filtered_df.groupby('Employee Name'):
    # Sort the group by Year to track movements sequentially
    group = group.sort_values(by='Year')
    
    # Track the previous city and average total pay
    prev_city = None
    prev_avg_pay = None
    prev_ft_exists = False
    prev_pt_exists = False
    
    for i, row in group.iterrows():
        current_city = row['Agency']
        current_ft_exists = group[(group['Agency'] == current_city) & (group['Status'] == 'FT')]['Adjusted Base Pay'].count() > 0
        current_pt_exists = group[(group['Agency'] == current_city) & (group['Status'] == 'PT')]['Adjusted Base Pay'].count() > 0
        
        if prev_city is not None and current_city != prev_city:
            if prev_ft_exists and current_ft_exists:
                # Compare FT average wage
                prev_city_avg_pay = group[(group['Agency'] == prev_city) & (group['Status'] == 'FT')]['Adjusted Base Pay'].mean()
                current_city_avg_pay = group[(group['Agency'] == current_city) & (group['Status'] == 'FT')]['Adjusted Base Pay'].mean()
            elif prev_pt_exists and current_pt_exists:
                # Compare PT average wage
                prev_city_avg_pay = group[(group['Agency'] == prev_city) & (group['Status'] == 'PT')]['Adjusted Base Pay'].mean()
                current_city_avg_pay = group[(group['Agency'] == current_city) & (group['Status'] == 'PT')]['Adjusted Base Pay'].mean()
            else:
                # If neither FT nor PT is available in both cities, continue to the next person
                continue
            
            # Add the name to the set if the average pay in the new city is higher than in the previous city
            if current_city_avg_pay > prev_city_avg_pay:
                selected_names.add(name)
        
        # Update the previous city and flags for the next iteration
        prev_city = current_city
        prev_ft_exists = current_ft_exists
        prev_pt_exists = current_pt_exists

# Filter the original DataFrame to include all entries for the selected names
filtered_movements_df = filtered_df[filtered_df['Employee Name'].isin(selected_names)]

print('# of Movements: ', filtered_movements_df['Employee Name'].nunique())

filtered_movements_df
# Out:
# # of Movements:  1265
#         Year       Agency        Employee Name                   Job Title  \
# 107     2013    Encinitas     Abalos, Jennifer  Human Resources Analyst Ii
# 108     2014    Encinitas     Abalos, Jennifer  Human Resources Analyst Ii
# 95      2015  Chula Vista     Abalos, Jennifer               Sr Hr Analyst
# 109     2015    Encinitas     Abalos, Jennifer                Not Provided
# 96      2016  Chula Vista     Abalos, Jennifer               Sr Hr Analyst
# ...      ...          ...                  ...                         ...
# 282671  2016  Chula Vista  Zimmer, Christopher               Peace Officer
# 282672  2017  Chula Vista  Zimmer, Christopher               Peace Officer
# 282673  2018  Chula Vista  Zimmer, Christopher               Peace Officer
# 282674  2019  Chula Vista  Zimmer, Christopher                Police Agent
# 282675  2020  Chula Vista  Zimmer, Christopher                Police Agent
#
#        Status   Base Pay  Overtime Pay  Other Pay  Total Pay  Benefits  ...  \
# 107        PT    1270.54          0.00       0.91    1271.45       NaN  ...
# 108        FT   75357.88          0.00    5681.02   81038.90       NaN  ...
# 95         PT   29704.14          0.00       0.00   29704.14       NaN  ...
# 109        FT   44097.24        761.67    7891.23   52750.14       NaN  ...
# 96         FT   88196.00          0.00   10870.00   99066.00       NaN  ...
# ...       ...        ...           ...        ...        ...       ...  ...
# 282671     FT   85992.00       9578.00    4860.00  100430.00       NaN  ...
# 282672     FT   90253.00      14148.00    4780.00  109181.00       NaN  ...
# 282673     FT   92612.00      36714.00    5484.00  134810.00       NaN  ...
# 282674     FT  100275.00      23711.00    8110.00  132096.00       NaN  ...
# 282675     FT  106296.00      28961.00    4906.00  140163.00       NaN  ...
#
#         Adjusted Base Pay  Adjusted Overtime Pay  Adjusted Other Pay  \
# 107           1661.834927               0.000000            1.190258
# 108          96992.839077               0.000000         7312.019110
# 95           38186.758192               0.000000            0.000000
# 109          56690.099117             979.180280        10144.730393
# 96          111969.640852               0.000000        13800.058915
# ...                   ...                    ...                 ...
# 282671      109171.542430           12159.794323         6170.035541
# 282672      112191.047675           17586.993701         5941.887892
# 282673      112378.633905           44550.049294         6654.477048
# 282674      119511.662305           28259.696085         9665.814822
# 282675      125143.845478           34096.211606         5775.906016
#
#         Adjusted Total Pay  Adjusted Benefits  Adjusted Pension Debt  \
# 107            1663.025184                NaN             322.232793
# 108          104304.858187                NaN           28411.785701
# 95            38186.758192                NaN           13124.257955
# 109           67814.009790                NaN           16060.706060
# 96           125769.699767                NaN           34931.795864
# ...                    ...                ...                    ...
# 282671       127501.372293                NaN           58973.352044
# 282672       135719.929267                NaN           62487.130600
# 282673       163583.160246                NaN           44311.002616
# 282674       157437.173213                NaN           47538.884811
# 282675       165015.963100                NaN           47678.891531
#
#         Adjusted Total Pay & Benefits  Adjusted 0 annual pension debt payment  \
# 107                       1985.257977                                     NaN
# 108                     132716.643888                                     NaN
# 95                       51311.016147                                     NaN
# 109                      83874.715849                                     NaN
# 96                      160701.495631                                     NaN
# ...                               ...                                     ...
# 282671                  186474.724337                                     NaN
# 282672                  198207.059867                                     NaN
# 282673                   19919.698949                                     NaN
# 282674                   27225.048674                                     NaN
# 282675                   31031.790895                                     NaN
#
#         Adjusted Notes  Adjusted Inflation Index
# 107                NaN                       1.0
# 108                NaN                       1.0
# 95                 NaN                       1.0
# 109                NaN                       1.0
# 96                 NaN                       1.0
# ...                ...                       ...
# 282671             NaN                       1.0
# 282672             NaN                       1.0
# 282673   227813.861812                       1.0
# 282674   232201.106697                       1.0
# 282675   243726.645526                       1.0
#
# [10948 rows x 25 columns]

# %%
filtered_movements_df.to_csv(f'C:/Users/Ericm/PycharmProjects/wageData/.venv/Scripts/sdcounty_salaries_names_movements.csv', index=False)

# %%
# Create an empty directed graph
G = nx.DiGraph()

# Add edges between cities for each individual who has worked in multiple cities
for name, group in filtered_movements_df.groupby('Employee Name'):
    cities = group['Agency'].unique()
    if len(cities) > 1:
        for i in range(len(cities) - 1):
            G.add_edge(cities[i], cities[i + 1])

# Draw the graph
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, seed=42)  # For consistent layout
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold', edge_color='gray')
plt.title("Employee Movements Between Cities")

plt.savefig(f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/sdcounty_movement.pdf", bbox_inches='tight')
plt.show()

# %%
# Group by 'Year' to calculate total number of employees and total aggregate salary
yearly_data = df.groupby('Year').agg(
    total_employees=('Employee Name', 'count'),  # Count of rows per year (total employees)
    total_salary=('Adjusted Base Pay', 'sum')  # Sum of 'Regular pay' per year (total salary)
).reset_index()

# Plotting the data
fig, ax1= plt.subplots()

# Plot total number of employees on the first axis
ax1.plot(yearly_data['Year'], yearly_data['total_employees'], color='blue', marker='o', label='Total # of Employees')
ax1.set_xlabel('Year')
ax1.set_ylabel('Total # of Employees', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Plot total salary on the second axis
ax2 = ax1.twinx()
ax2.plot(yearly_data['Year'], yearly_data['total_salary'], color='red', marker='o', label='Total Salary')
ax2.set_ylabel('Total Salary', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Adding a title
plt.title(f'Total Number of Employees and Total Real Salary Over Time')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show plot with legends
fig.tight_layout()  # Adjust layout to prevent overlap


plt.savefig(f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/sdcounty_salary_num_empls.pdf", bbox_inches='tight')

plt.show()

# %%
# Group by 'Year' to calculate total number of employees and total aggregate salary
yearly_data = df.groupby('Year').agg(
    total_employees=('Employee Name', 'count'),  # Count of rows per year (total employees)
    total_salary=('Adjusted Base Pay', 'sum')  # Sum of 'Regular pay' per year (total salary)
).reset_index()

# Plotting the data
fig, ax1 = plt.subplots()

# Plot total number of employees on the first axis
ax1.plot(yearly_data['Year'], yearly_data['total_salary']/yearly_data['total_employees'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Average Real Salary per Employee', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Adding a title
plt.title(f'Average Real Salary per Employee Over Time')

# Show plot with legends
fig.tight_layout()  # Adjust layout to prevent overlap

plt.savefig(f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/sdcounty_avg_salary", bbox_inches='tight')

plt.show()

# %%
grouped_df = df.groupby(['Year', 'Agency']).agg(
    PositionCount=('Job Title', 'size'),
    MedianWages=('Adjusted Base Pay', 'median')
).reset_index()

grouped_df.columns = ['Year', 'Agency', 'NumEmpls', 'AdjMedWage']
grouped_df
# Out:
#      Year       Agency  NumEmpls    AdjMedWage
# 0    2011     Carlsbad      1190  60793.541219
# 1    2011  Chula Vista      1271  77443.309241
# 2    2011     Coronado       592  16765.660684
# 3    2011     El Cajon       568  76755.796390
# 4    2011    Encinitas       363  83647.803191
# ..    ...          ...       ...           ...
# 216  2023     El Cajon       548  70161.500000
# 217  2023    Encinitas       432  62967.000000
# 218  2023    Escondido      1171  51593.000000
# 219  2023    Oceanside      1456  58842.000000
# 220  2023    San Diego     13879  61521.000000
#
# [221 rows x 4 columns]

# %%
grouped_df['NumEmpls%Chg'] = grouped_df.groupby(['Agency'])['NumEmpls'].pct_change()
grouped_df['AdjMedWage%Chg'] = grouped_df.groupby(['Agency'])['AdjMedWage'].pct_change()

#grouped_df.to_csv(f"C:/Users/Ericm\PycharmProjects\wageData\.venv\Scripts/{position}_RoC.csv")

grouped_df
# Out:
#      Year       Agency  NumEmpls    AdjMedWage  NumEmpls%Chg  AdjMedWage%Chg
# 0    2011     Carlsbad      1190  60793.541219           NaN             NaN
# 1    2011  Chula Vista      1271  77443.309241           NaN             NaN
# 2    2011     Coronado       592  16765.660684           NaN             NaN
# 3    2011     El Cajon       568  76755.796390           NaN             NaN
# 4    2011    Encinitas       363  83647.803191           NaN             NaN
# ..    ...          ...       ...           ...           ...             ...
# 216  2023     El Cajon       548  70161.500000      0.047801        0.083227
# 217  2023    Encinitas       432  62967.000000      0.053659        0.055591
# 218  2023    Escondido      1171  51593.000000     -0.003404       -0.120212
# 219  2023    Oceanside      1456  58842.000000      0.021754        0.029221
# 220  2023    San Diego     13879  61521.000000      0.081761        0.029683
#
# [221 rows x 6 columns]

# %%
# Convert 'Agency' to numeric codes if necessary
grouped_df['Agency'] = grouped_df['Agency'].astype('category').cat.codes
grouped_df['Year'] = pd.to_numeric(grouped_df['Year'])

# Create a lagged variable for NumEmpls%Chg by shifting it by 1 year within each city
#grouped_filtered_df['NumEmpls%Chg_Lagged'] = grouped_filtered_df.groupby('City')['NumEmpls%Chg'].shift(1)

# Define the dependent variable
y = pd.to_numeric(grouped_df['AdjMedWage'], errors='coerce')

# Define the independent variables
X = grouped_df[['Agency', 'Year', 'NumEmpls%Chg']]

# Add a constant term to the independent variables
X = sm.add_constant(X)

# Drop missing values that resulted from the lagging operation
X = X.dropna()
y = y[X.index]

# Fit the OLS regression model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             AdjMedWage   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.217
# Date:                Fri, 30 Aug 2024   Prob (F-statistic):              0.305
# Time:                        23:45:24   Log-Likelihood:                -2333.9
# No. Observations:                 203   AIC:                             4676.
# Df Residuals:                     199   BIC:                             4689.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -4.932e+05   1.05e+06     -0.471      0.638   -2.56e+06    1.57e+06
# Agency        -516.4672    325.265     -1.588      0.114   -1157.876     124.942
# Year           269.3355    519.154      0.519      0.604    -754.414    1293.085
# NumEmpls%Chg  -133.4999    167.230     -0.798      0.426    -463.270     196.270
# ==============================================================================
# Omnibus:                      285.218   Durbin-Watson:                   2.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.916
# Skew:                          -0.360   Prob(JB):                     4.73e-05
# Kurtosis:                       1.645   Cond. No.                     1.25e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Time-series plot of wage w/ markers indicating positive or negative change in # of employees
'''
# If position is not null, filter for that position only
def plot_wage_timeseries(df, position, filter, save_path=None):
    # Convert columns to appropriate types
    df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
    df['NumEmpls%Chg'] = pd.to_numeric(df['NumEmpls%Chg'], errors='coerce')
    df['AdjMedWage'] = pd.to_numeric(df['AdjMedWage'], errors='coerce')
    
    # Filter by position if provided
    if filter:
        df = df[df['Job Title'] == filter]
    
    # Get a list of cities in the dataset
    agencies = df['Agency'].unique()
    
    # Use a distinct color map that can generate unique colors for each city
    num_agencies = len(agencies)
    cmap = plt.get_cmap('tab20', num_agencies)  # 'tab20' is good for categorical data with many distinct colors
    
    # Plotting
    plt.figure(figsize=(14, 8))

    agency_colors = {}

    for i, agency in enumerate(agencies):
        agency_data = df[df['Agency'] == agency]
        
        # Separate the data into positive and negative employee change
        positive_change = agency_data[agency_data['NumEmpls%Chg'] > 0]
        negative_change = agency_data[agency_data['NumEmpls%Chg'] <= 0]
        
        # Assign and store a unique color for each city from the colormap
        color = cmap(i)
        agency_colors[agency] = color
        
        # Plot time-series for the city without markers on the line
        plt.plot(agency_data['Year'], agency_data['AdjMedWage'], label=agency, color=color, linestyle='-', linewidth=2, zorder=1)
        
        # Overlay smaller markers for positive and negative employee changes with higher zorder
        plt.scatter(positive_change['Year'], positive_change['AdjMedWage'], 
                    color='green', marker='^', s=80, edgecolor='black', alpha=0.8, zorder=2)
        plt.scatter(negative_change['Year'], negative_change['AdjMedWage'], 
                    color='red', marker='v', s=80, edgecolor='black', alpha=0.8, zorder=2)
    
    plt.title(f'Adjusted Median Wage Time-Series by Agency')
    plt.xlabel('Year')
    plt.ylabel('Adjusted Median Wages')
    
    # Create custom handles for the legend to only show one instance of the markers
    custom_handles = [
        plt.Line2D([0], [0], marker='^', color='w', markerfacecolor='green', markersize=10, label='Positive Change in # of Employees', markeredgecolor='black'),
        plt.Line2D([0], [0], marker='v', color='w', markerfacecolor='red', markersize=10, label='Negative Change in # of Employees', markeredgecolor='black')
    ]
    
    # Add agency-specific handles with unique colors
    agencies_handles = [plt.Line2D([0], [0], color=agency_colors[agency], label=agency) for agency in agencies]
    
    plt.legend(handles=custom_handles + agencies_handles, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='small')
    
    plt.grid(True)
    
    
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')  # Use bbox_inches='tight' to avoid cutting off the legend
    
    
    plt.show()

# Example usage with your DataFrame
plot_wage_timeseries(grouped_df, position=position, filter = None, save_path=f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/sdcounty_salary_num_empls_roc.pdf")
'''
# Out:
# '\n# If position is not null, filter for that position only\ndef plot_wage_timeseries(df, position, filter, save_path=None):\n    # Convert columns to appropriate types\n    df[\'Year\'] = pd.to_numeric(df[\'Year\'], errors=\'coerce\')\n    df[\'NumEmpls%Chg\'] = pd.to_numeric(df[\'NumEmpls%Chg\'], errors=\'coerce\')\n    df[\'AdjMedWage\'] = pd.to_numeric(df[\'AdjMedWage\'], errors=\'coerce\')\n    \n    # Filter by position if provided\n    if filter:\n        df = df[df[\'Job Title\'] == filter]\n    \n    # Get a list of cities in the dataset\n    agencies = df[\'Agency\'].unique()\n    \n    # Use a distinct color map that can generate unique colors for each city\n    num_agencies = len(agencies)\n    cmap = plt.get_cmap(\'tab20\', num_agencies)  # \'tab20\' is good for categorical data with many distinct colors\n    \n    # Plotting\n    plt.figure(figsize=(14, 8))\n\n    agency_colors = {}\n\n    for i, agency in enumerate(agencies):\n        agency_data = df[df[\'Agency\'] == agency]\n        \n        # Separate the data into positive and negative employee change\n        positive_change = agency_data[agency_data[\'NumEmpls%Chg\'] > 0]\n        negative_change = agency_data[agency_data[\'NumEmpls%Chg\'] <= 0]\n        \n        # Assign and store a unique color for each city from the colormap\n        color = cmap(i)\n        agency_colors[agency] = color\n        \n        # Plot time-series for the city without markers on the line\n        plt.plot(agency_data[\'Year\'], agency_data[\'AdjMedWage\'], label=agency, color=color, linestyle=\'-\', linewidth=2, zorder=1)\n        \n        # Overlay smaller markers for positive and negative employee changes with higher zorder\n        plt.scatter(positive_change[\'Year\'], positive_change[\'AdjMedWage\'], \n                    color=\'green\', marker=\'^\', s=80, edgecolor=\'black\', alpha=0.8, zorder=2)\n        plt.scatter(negative_change[\'Year\'], negative_change[\'AdjMedWage\'], \n                    color=\'red\', marker=\'v\', s=80, edgecolor=\'black\', alpha=0.8, zorder=2)\n    \n    plt.title(f\'Adjusted Median Wage Time-Series by Agency\')\n    plt.xlabel(\'Year\')\n    plt.ylabel(\'Adjusted Median Wages\')\n    \n    # Create custom handles for the legend to only show one instance of the markers\n    custom_handles = [\n        plt.Line2D([0], [0], marker=\'^\', color=\'w\', markerfacecolor=\'green\', markersize=10, label=\'Positive Change in # of Employees\', markeredgecolor=\'black\'),\n        plt.Line2D([0], [0], marker=\'v\', color=\'w\', markerfacecolor=\'red\', markersize=10, label=\'Negative Change in # of Employees\', markeredgecolor=\'black\')\n    ]\n    \n    # Add agency-specific handles with unique colors\n    agencies_handles = [plt.Line2D([0], [0], color=agency_colors[agency], label=agency) for agency in agencies]\n    \n    plt.legend(handles=custom_handles + agencies_handles, loc=\'center left\', bbox_to_anchor=(1, 0.5), fontsize=\'small\')\n    \n    plt.grid(True)\n    \n    \n    if save_path:\n        plt.savefig(save_path, bbox_inches=\'tight\')  # Use bbox_inches=\'tight\' to avoid cutting off the legend\n    \n    \n    plt.show()\n\n# Example usage with your DataFrame\nplot_wage_timeseries(grouped_df, position=position, filter = None, save_path=f"C:/Users\\Ericm\\PycharmProjects\\wageData\\.venv\\Scripts/sdcounty_salary_num_empls_roc.pdf")\n'

# %%
# Code from unused methods
'''
def capitalize_column(name):
    return name.upper().strip()


file_path_2 = f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/{employer_type}_sd_salaries_publicpay.csv"

nameless_df = pd.read_csv(file_path_2, encoding='latin1')

nameless_df['Position'] = nameless_df['Position'].apply(capitalize_column)

if employer_type == 'k12':
    filter = nameless_df['EmployerName'].str.contains('|'.join(school_districts), case=False, na=False)
elif employer_type == 'cities':
    filter = ~(nameless_df['Year'] < 2011)

nameless_df = nameless_df[filter]

nameless_df

#################################################################################################################

# Check for duplicates
duplicates = nameless_df.duplicated()

# Display the number of duplicate rows found
num_duplicates = duplicates.sum()
print(f"Number of duplicate rows found: {num_duplicates}")
if num_duplicates > 0:
    # Remove duplicates
    nameless_df = nameless_df.drop_duplicates()
    nameless_df.to_csv(file_path_2, index=False)
    print(f"{num_duplicates} duplicate rows dropped")
    
#################################################################################################################

from rapidfuzz import process, fuzz


# Function to find the best match for a job title within a list of candidates
def find_best_match(job_title, candidates):
    best_match, score, i = process.extractOne(job_title.upper(), candidates, scorer=fuzz.WRatio)
    return best_match, score


# Create a dictionary to store best matches for unique positions
position_match_dict = {}

for year in df['Year'].unique():
    position_match_dict[int(year)] = {}
    for agency in df['Agency'].unique():
        position_match_dict[int(year)][str(agency)] = {}


# Function to find the closest year with available data
def find_closest_year(agency, year, df):
    available_years = df[df['EmployerName'] == agency]['Year'].unique()
    if len(available_years) == 0:
        return None
    closest_year = min(available_years, key=lambda x: abs(x - year))
    return closest_year


# Iterate through each unique combination of agency and year in the df
for (agency, year), group in df.groupby(['Agency', 'Year']):
    # Get unique job titles for this agency and year
    unique_positions = group['Job Title'].unique().tolist()

    # Filter the nameless_df for the same agency and year
    filtered_nameless_df = nameless_df[
        (nameless_df['EmployerName'].str.contains(str(agency).strip(), case=False)) &
        (nameless_df['Year'] == int(year))
        ]

    if not filtered_nameless_df.empty:
        # If data for the current year exists, proceed with matching
        agency_positions = filtered_nameless_df['Position'].unique().tolist()
        for indiv_position in unique_positions:
            best_match, score = find_best_match(indiv_position, agency_positions)
            if best_match:
                position_match_dict[int(year)][str(agency)][indiv_position] = [int(year), best_match.strip(), score]
            else:
                print(f'No Match Found for {indiv_position} in {year} {agency}')
                position_match_dict[int(year)][str(agency)][indiv_position] = [None, None, None]
    else:
        # If no data for the current year, find the closest year
        closest_year = find_closest_year(agency, int(year), nameless_df)
        if closest_year is not None:
            print(f'Using data from closest year {closest_year} for {year} {agency}')
            filtered_closest_df = nameless_df[
                (nameless_df['EmployerName'].str.contains(str(agency).strip(), case=False)) &
                (nameless_df['Year'] == closest_year)
                ]
            agency_positions = filtered_closest_df['Position'].unique().tolist()
            for indiv_position in unique_positions:
                best_match, score = find_best_match(indiv_position, agency_positions)
                if best_match:
                    position_match_dict[int(year)][str(agency)][indiv_position] = [int(closest_year),
                                                                                   best_match.strip(), score]
                else:
                    print(f'No Match Found for {indiv_position} in {year} {agency} using closest year {closest_year}')
                    position_match_dict[int(year)][str(agency)][indiv_position] = [None, None, None]
        else:
            # If no closest year is found, proceed with None
            print(f'No data available for any year for {agency}')
            for indiv_position in unique_positions:
                position_match_dict[int(year)][str(agency)][indiv_position] = [None, None, None]
                
#################################################################################################################

with open(f"C:/Users\Ericm\PycharmProjects\wageData\.venv\Scripts/{employer_type}_sd_salaries_corrected_positions.txt",
          'r') as file:
    for line in file:
        line = line.strip()
        elems = line.split(' | ')
        elems2 = elems[2].split(' : ')
        year = int(elems[0][0:4])
        agency = elems[0][5:]
        indiv_position = elems[1]
        match = elems2[0]
        match_year = elems2[1]
        position_match_dict[year][agency][indiv_position] = []
        position_match_dict[year][agency][indiv_position].append(int(match_year))
        position_match_dict[year][agency][indiv_position].append(match.strip())
        position_match_dict[year][agency][indiv_position].append(100)
        
#################################################################################################################
        
for year in position_match_dict:
    for agency in position_match_dict[year]:
        for indiv_position in position_match_dict[year][agency]:
            if pd.isna(position_match_dict[year][agency][indiv_position][1]) == True or \
                    position_match_dict[year][agency][indiv_position][2] <= 50:
                print(year, agency, '|', indiv_position, '|', position_match_dict[year][agency][indiv_position][1], ':',
                      position_match_dict[year][agency][indiv_position][0])
                      
#################################################################################################################

# Prepare lists to hold the results
min_salaries = []
max_salaries = []

for (agency, year), group in df.groupby(['Agency', 'Year']):
    
    # Filter the nameless dataframe for the same city and year
    filtered_nameless_df = nameless_df[
        (nameless_df['EmployerName'].str.contains(str(agency).strip(), case=False)) &
        (nameless_df['Year'] == int(year))
    ]
    
    if not filtered_nameless_df.empty:
        # Now, iterate through the original group to assign salaries based on the best match
        for index, row in group.iterrows():
            job_title = str(row['Job Title'])
            
            
            best_match = str(position_match_dict[int(year)][str(agency)].get(job_title)[1]).strip()
            
            match_year = position_match_dict[int(year)][str(agency)].get(job_title)[0]
            if match_year != int(year):
                filtered_nameless_df = nameless_df[
                    (nameless_df['EmployerName'].str.contains(str(agency).strip(), case=False)) &
                    (nameless_df['Year'] == int(match_year))
                ]
            
            matched_rows = filtered_nameless_df[filtered_nameless_df['Position'].str.contains(best_match, case=False, na=False, regex=False)]
            
            if not matched_rows.empty:
                min_salaries_list = matched_rows['MinPositionSalary'].values
                # Filter for salaries greater than 0
                min_salaries_gt_0 = min_salaries_list[min_salaries_list > 0]
                
                # Check if there are any salaries greater than 0
                if len(min_salaries_gt_0) > 0:
                    min_salaries.append(min_salaries_gt_0.min())
                else:
                    min_salaries.append(None)  # or append None
                    
                max_salaries.append(matched_row['MaxPositionSalary'].values.max())
            else:
                print(year, agency, job_title, best_match)
                min_salaries.append(None)
                max_salaries.append(None)
    else:
        # If no match is found, append None or some default value for the entire group
        min_salaries.extend([None] * len(group))
        max_salaries.extend([None] * len(group))

# Attach the results to the DataFrame
df['MinPositionSalary'] = min_salaries
df['MaxPositionSalary'] = max_salaries

df

#################################################################################################################

# Define a function to determine 'FT or PT' status
def determine_ft_or_pt(row):
    if pd.isna(row['Status']) == True:
        if pd.isna(row['MinPositionSalary']) or row['MinPositionSalary'] <= 0:
            if 0 < row['Base Pay'] < 30000:
                return 'PT'
            elif row['Base Pay'] >= 30000:
                return 'FT'
            else:
                return ''
        elif row['Base Pay'] >= row['MinPositionSalary']*0.9:
            return 'FT'
        elif 0 < row['Base Pay'] < row['MinPositionSalary']*0.9:
            return 'PT'
        else:
            return ''

# Apply the function to each row to create the 'FT or PT' column
df['Status'] = df.apply(determine_ft_or_pt, axis=1)

# Display the updated DataFrame
df

#################################################################################################################
'''
# Out:
# '\ndef capitalize_column(name):\n    return name.upper().strip()\n\n\nfile_path_2 = f"C:/Users\\Ericm\\PycharmProjects\\wageData\\.venv\\Scripts/{employer_type}_sd_salaries_publicpay.csv"\n\nnameless_df = pd.read_csv(file_path_2, encoding=\'latin1\')\n\nnameless_df[\'Position\'] = nameless_df[\'Position\'].apply(capitalize_column)\n\nif employer_type == \'k12\':\n    filter = nameless_df[\'EmployerName\'].str.contains(\'|\'.join(school_districts), case=False, na=False)\nelif employer_type == \'cities\':\n    filter = ~(nameless_df[\'Year\'] < 2011)\n\nnameless_df = nameless_df[filter]\n\nnameless_df\n\n#################################################################################################################\n\n# Check for duplicates\nduplicates = nameless_df.duplicated()\n\n# Display the number of duplicate rows found\nnum_duplicates = duplicates.sum()\nprint(f"Number of duplicate rows found: {num_duplicates}")\nif num_duplicates > 0:\n    # Remove duplicates\n    nameless_df = nameless_df.drop_duplicates()\n    nameless_df.to_csv(file_path_2, index=False)\n    print(f"{num_duplicates} duplicate rows dropped")\n    \n#################################################################################################################\n\nfrom rapidfuzz import process, fuzz\n\n\n# Function to find the best match for a job title within a list of candidates\ndef find_best_match(job_title, candidates):\n    best_match, score, i = process.extractOne(job_title.upper(), candidates, scorer=fuzz.WRatio)\n    return best_match, score\n\n\n# Create a dictionary to store best matches for unique positions\nposition_match_dict = {}\n\nfor year in df[\'Year\'].unique():\n    position_match_dict[int(year)] = {}\n    for agency in df[\'Agency\'].unique():\n        position_match_dict[int(year)][str(agency)] = {}\n\n\n# Function to find the closest year with available data\ndef find_closest_year(agency, year, df):\n    available_years = df[df[\'EmployerName\'] == agency][\'Year\'].unique()\n    if len(available_years) == 0:\n        return None\n    closest_year = min(available_years, key=lambda x: abs(x - year))\n    return closest_year\n\n\n# Iterate through each unique combination of agency and year in the df\nfor (agency, year), group in df.groupby([\'Agency\', \'Year\']):\n    # Get unique job titles for this agency and year\n    unique_positions = group[\'Job Title\'].unique().tolist()\n\n    # Filter the nameless_df for the same agency and year\n    filtered_nameless_df = nameless_df[\n        (nameless_df[\'EmployerName\'].str.contains(str(agency).strip(), case=False)) &\n        (nameless_df[\'Year\'] == int(year))\n        ]\n\n    if not filtered_nameless_df.empty:\n        # If data for the current year exists, proceed with matching\n        agency_positions = filtered_nameless_df[\'Position\'].unique().tolist()\n        for indiv_position in unique_positions:\n            best_match, score = find_best_match(indiv_position, agency_positions)\n            if best_match:\n                position_match_dict[int(year)][str(agency)][indiv_position] = [int(year), best_match.strip(), score]\n            else:\n                print(f\'No Match Found for {indiv_position} in {year} {agency}\')\n                position_match_dict[int(year)][str(agency)][indiv_position] = [None, None, None]\n    else:\n        # If no data for the current year, find the closest year\n        closest_year = find_closest_year(agency, int(year), nameless_df)\n        if closest_year is not None:\n            print(f\'Using data from closest year {closest_year} for {year} {agency}\')\n            filtered_closest_df = nameless_df[\n                (nameless_df[\'EmployerName\'].str.contains(str(agency).strip(), case=False)) &\n                (nameless_df[\'Year\'] == closest_year)\n                ]\n            agency_positions = filtered_closest_df[\'Position\'].unique().tolist()\n            for indiv_position in unique_positions:\n                best_matc ...
